# %%
import requests
import pandas as pd

def fetch_comments():
    url = "https://m.ctrip.com/restapi/soa2/13444/json/getCommentCollapseList"
    headers = {
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    payload = {
        "arg": {
            "channelType": 2,
            "collapseType": 0,
            "commentTagId": 0,
            "pageIndex": 1,
            "pageSize": 10,
            "poiId": 81801,
            "sourceType": 1,
            "sortType": 3,
            "starType": 0
        },
        "head": {
            "cid": "09031058213352606128",
            "ctok": "",
            "cver": "1.0",
            "lang": "01",
            "sid": "8888",
            "syscode": "09",
            "auth": "",
            "xsid": "",
            "extension": []
        }
    }

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code == 200:
        data = response.json()
        comments = data.get("result", {}).get("items", [])

        processed_data = []

        for comment in comments:
            processed_data.append({
                "Comment ID": comment.get("commentId"),
                "User Nick": comment.get("userInfo", {}).get("userNick"),
                "User Image": comment.get("userInfo", {}).get("userImage"),
                "Comment Content": comment.get("content"),
                "Publish Time": comment.get("publishTypeTag"),
                "Useful Count": comment.get("usefulCount"),
                "Score": comment.get("score"),
                "Images": [img.get("imageSrcUrl") for img in comment.get("images", [])]
            })

        df = pd.DataFrame(processed_data)
        return df

    else:
        print(f"Failed to fetch data. Status code: {response.status_code}")
        return None

# Fetch comments and save to a DataFrame
dataframe = fetch_comments()
if dataframe is not None:
    # Display the DataFrame
    print(dataframe)
    # Optionally save to a CSV file
    dataframe.to_csv("comments.csv", index=False)
# Out:
#    Comment ID     User Nick  \
# 0   107267523        远行-遇见你
# 1    92580773   132****2066
# 2    71514243          阿断断断
# 3    70847520   chri****_17
# 4    69665032       1990有43
# 5    69086037  littlehottie
# 6    60015644     lmjazzman
# 7    58875840           臭苗苗
# 8    74205518         老力123
# 9    87044839         行程的会员
#
#                                           User Image  \
# 0  https://dimg04.c-ctrip.com/images/0Z80g1200084...
# 1  https://dimg04.c-ctrip.com/images/fd/headphoto...
# 2  https://dimg04.c-ctrip.com/images/fd/headphoto...
# 3  https://dimg04.c-ctrip.com/images/fd/headphoto...
# 4  https://dimg04.c-ctrip.com/images/Z80j17000001...
# 5  https://dimg04.c-ctrip.com/images/t1/headphoto...
# 6  https://dimg04.c-ctrip.com/images/fd/headphoto...
# 7  https://dimg04.c-ctrip.com/images/fd/headphoto...
# 8  https://dimg04.c-ctrip.com/images/Z80o18000001...
# 9  https://dimg04.c-ctrip.com/images/Z80618000001...
#
#                                      Comment Content     Publish Time  \
# 0  登上汉拿山顶可以远眺整个济州市，从城板岳线路上然后观音寺线路下，一路上风景美不胜收，映入眼眸...  2017-05-18 发布点评
# 1  在公车上看到一群老人穿着运动装，下车后跟着他们走就找到登山的路了，建议一定要穿专门的登山鞋，...  2016-12-01 发布点评
# 2  汉拿山，世遗，免费。问询处提供中文地图，一位中文很好的大姐把每段路用时多少公交信息都帮忙写在...  2016-03-13 发布点评
# 3  我们是2月份去的，山脚下就全是雪，可见山上的积雪有多厚。选择的是城板岳路线，单程9.6km，...  2016-02-14 发布点评
# 4  极少有中国人，即便有1.不到顶2.装备不专业。所以如果爬，1.装备一定要专业（韩国人都巨专业...  2016-01-12 发布点评
# 5  在汉拿山医院门口，坐740，可以到达御里牧登山口…最早一班车是6点半，下一班是8点，之后是一...  2016-01-03 发布点评
# 6  汉拿山在济州岛中部，是韩国境内海拔最高的一座山，她也是一座休眠火山。我们去的时候正是冬季，汉...  2015-11-13 发布点评
# 7  来济州岛第三次终于来了汉拿山，当初是看了金三顺，超想来，但同伴身体不适，我们就选择了最平缓的...  2015-10-19 发布点评
# 8  我是从灵室上山到威势岳庇护所，再向顿乃克方向走到主峰山脚下，回头从御里牧下山。全程山路部分用...  2016-05-12 发布点评
# 9  汉拿山在济州岛的中心地带，有很多可以上山的门和入口。入口自驾车停车场很方便，停车场要按次收费...  2016-09-02 发布点评
#
#    Useful Count  Score                                             Images
# 0            11    5.0  [https://dimg04.c-ctrip.com/images/100e0g00000...
# 1            25    5.0  [https://dimg04.c-ctrip.com/images/100v0b00000...
# 2            85    5.0  [https://dimg04.c-ctrip.com/images/fd/tg/g4/M0...
# 3            25    5.0  [https://dimg04.c-ctrip.com/images/fd/tg/g4/M0...
# 4            18    5.0  [https://dimg04.c-ctrip.com/images/fd/tg/g3/M0...
# 5            48    5.0  [https://dimg04.c-ctrip.com/images/fd/tg/g4/M0...
# 6            13    5.0  [https://dimg04.c-ctrip.com/images/fd/tg/g3/M0...
# 7            22    5.0  [https://dimg04.c-ctrip.com/images/fd/tg/g3/M0...
# 8            27    5.0  [https://dimg04.c-ctrip.com/images/fd/tg/g5/M0...
# 9            33    5.0  [https://dimg04.c-ctrip.com/images/100g0800000...

# %%
import requests
import pandas as pd

def fetch_comments(page_limit=60):
    url = "https://m.ctrip.com/restapi/soa2/13444/json/getCommentCollapseList"
    headers = {
        "Content-Type": "application/json",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    all_comments = []

    for page in range(1, page_limit + 1):
        payload = {
            "arg": {
                "channelType": 2,
                "collapseType": 0,
                "commentTagId": 0,
                "pageIndex": page,
                "pageSize": 10,
                "poiId": 81801,
                "sourceType": 1,
                "sortType": 3,
                "starType": 0
            },
            "head": {
                "cid": "09031058213352606128",
                "ctok": "",
                "cver": "1.0",
                "lang": "01",
                "sid": "8888",
                "syscode": "09",
                "auth": "",
                "xsid": "",
                "extension": []
            }
        }

        response = requests.post(url, headers=headers, json=payload)

        if response.status_code == 200:
            data = response.json()
            comments = data.get("result", {}).get("items", [])

            for comment in comments:
                user_info = comment.get("userInfo") or {}
                all_comments.append({
                    "Comment ID": comment.get("commentId"),
                    "User Nick": user_info.get("userNick", "N/A"),
                    "User Image": user_info.get("userImage", "N/A"),
                    "Comment Content": comment.get("content", "N/A"),
                    "Publish Time": comment.get("publishTypeTag", "N/A"),
                    "Useful Count": comment.get("usefulCount", 0),
                    "Score": comment.get("score", 0.0),
                    "Images": [img.get("imageSrcUrl", "N/A") for img in comment.get("images", [])]
                })
        else:
            print(f"Failed to fetch data for page {page}. Status code: {response.status_code}")

    df = pd.DataFrame(all_comments)
    return df

# Fetch comments from 60 pages and save to a DataFrame
dataframe = fetch_comments(page_limit=60)
if dataframe is not None:
    # Display the DataFrame
    print(dataframe)
    # Optionally save to a CSV file
    dataframe.to_csv("comments_60_pages.csv", index=False)
# Out:
#      Comment ID            User Nick  \
# 0     107267523               远行-遇见你
# 1      92580773          132****2066
# 2      71514243                 阿断断断
# 3      70847520          chri****_17
# 4      69665032              1990有43
# ..          ...                  ...
# 587    89126117                 geer
# 588    79451123  Little_monster_2018
# 589   141595045          137****5124
# 590    99461898                 AA杨素
# 591   200329124                   친구
#
#                                             User Image  \
# 0    https://dimg04.c-ctrip.com/images/0Z80g1200084...
# 1    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 2    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 3    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 4    https://dimg04.c-ctrip.com/images/Z80j17000001...
# ..                                                 ...
# 587  https://dimg04.c-ctrip.com/images/Z80i0w000000...
# 588  https://dimg04.c-ctrip.com/images/Z8090o000000...
# 589  https://dimg04.c-ctrip.com/images/Z80o18000001...
# 590  https://dimg04.c-ctrip.com/images/Z80t14000000...
# 591  https://dimg04.c-ctrip.com/images/Z80o18000001...
#
#                                        Comment Content     Publish Time  \
# 0    登上汉拿山顶可以远眺整个济州市，从城板岳线路上然后观音寺线路下，一路上风景美不胜收，映入眼眸...  2017-05-18 发布点评
# 1    在公车上看到一群老人穿着运动装，下车后跟着他们走就找到登山的路了，建议一定要穿专门的登山鞋，...  2016-12-01 发布点评
# 2    汉拿山，世遗，免费。问询处提供中文地图，一位中文很好的大姐把每段路用时多少公交信息都帮忙写在...  2016-03-13 发布点评
# 3    我们是2月份去的，山脚下就全是雪，可见山上的积雪有多厚。选择的是城板岳路线，单程9.6km，...  2016-02-14 发布点评
# 4    极少有中国人，即便有1.不到顶2.装备不专业。所以如果爬，1.装备一定要专业（韩国人都巨专业...  2016-01-12 发布点评
# ..                                                 ...              ...
# 587                                    一般吧，反正是座山，不算壮观。  2016-10-02 发布点评
# 588            我们来到汉拿山公园的时候正好是阴天 山上雾蒙蒙的 也没有什么可看 能见度特别低  2016-07-01 发布点评
# 589  小伙伴们，给大家发红包喽！人人可领，领完就能用。祝大家领取的红包金额大大大！#吱口令#长按复...  2017-11-06 发布点评
# 590                                  携程个垃圾还在销售韩国旅游产品呀？  2017-03-18 发布点评
# 591                             在下雪的汉拿山山顶感受到的成就感。最好的礼物  2024-12-25 发布点评
#
#      Useful Count  Score                                             Images
# 0              11    5.0  [https://dimg04.c-ctrip.com/images/100e0g00000...
# 1              25    5.0  [https://dimg04.c-ctrip.com/images/100v0b00000...
# 2              85    5.0  [https://dimg04.c-ctrip.com/images/fd/tg/g4/M0...
# 3              25    5.0  [https://dimg04.c-ctrip.com/images/fd/tg/g4/M0...
# 4              18    5.0  [https://dimg04.c-ctrip.com/images/fd/tg/g3/M0...
# ..            ...    ...                                                ...
# 587             0    3.0                                                 []
# 588             0    3.0                                                 []
# 589             2    1.0                                                 []
# 590             3    1.0                                                 []
# 591             0    5.0                                                 []
#
# [592 rows x 8 columns]

# %%
# prompt: 판다스 데이터 프레임으로 comments_60_pages.csv 불러오기

import pandas as pd

df = pd.read_csv('comments_60_pages.csv')
df
# Out:
#      Comment ID            User Nick  \
# 0     107267523               远行-遇见你
# 1      92580773          132****2066
# 2      71514243                 阿断断断
# 3      70847520          chri****_17
# 4      69665032              1990有43
# ..          ...                  ...
# 587    89126117                 geer
# 588    79451123  Little_monster_2018
# 589   141595045          137****5124
# 590    99461898                 AA杨素
# 591   200329124                   친구
#
#                                             User Image  \
# 0    https://dimg04.c-ctrip.com/images/0Z80g1200084...
# 1    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 2    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 3    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 4    https://dimg04.c-ctrip.com/images/Z80j17000001...
# ..                                                 ...
# 587  https://dimg04.c-ctrip.com/images/Z80i0w000000...
# 588  https://dimg04.c-ctrip.com/images/Z8090o000000...
# 589  https://dimg04.c-ctrip.com/images/Z80o18000001...
# 590  https://dimg04.c-ctrip.com/images/Z80t14000000...
# 591  https://dimg04.c-ctrip.com/images/Z80o18000001...
#
#                                        Comment Content     Publish Time  \
# 0    登上汉拿山顶可以远眺整个济州市，从城板岳线路上然后观音寺线路下，一路上风景美不胜收，映入眼眸...  2017-05-18 发布点评
# 1    在公车上看到一群老人穿着运动装，下车后跟着他们走就找到登山的路了，建议一定要穿专门的登山鞋，...  2016-12-01 发布点评
# 2    汉拿山，世遗，免费。问询处提供中文地图，一位中文很好的大姐把每段路用时多少公交信息都帮忙写在...  2016-03-13 发布点评
# 3    我们是2月份去的，山脚下就全是雪，可见山上的积雪有多厚。选择的是城板岳路线，单程9.6km，...  2016-02-14 发布点评
# 4    极少有中国人，即便有1.不到顶2.装备不专业。所以如果爬，1.装备一定要专业（韩国人都巨专业...  2016-01-12 发布点评
# ..                                                 ...              ...
# 587                                    一般吧，反正是座山，不算壮观。  2016-10-02 发布点评
# 588            我们来到汉拿山公园的时候正好是阴天 山上雾蒙蒙的 也没有什么可看 能见度特别低  2016-07-01 发布点评
# 589  小伙伴们，给大家发红包喽！人人可领，领完就能用。祝大家领取的红包金额大大大！#吱口令#长按复...  2017-11-06 发布点评
# 590                                  携程个垃圾还在销售韩国旅游产品呀？  2017-03-18 发布点评
# 591                             在下雪的汉拿山山顶感受到的成就感。最好的礼物  2024-12-25 发布点评
#
#      Useful Count  Score                                             Images
# 0              11    5.0  ['https://dimg04.c-ctrip.com/images/100e0g0000...
# 1              25    5.0  ['https://dimg04.c-ctrip.com/images/100v0b0000...
# 2              85    5.0  ['https://dimg04.c-ctrip.com/images/fd/tg/g4/M...
# 3              25    5.0  ['https://dimg04.c-ctrip.com/images/fd/tg/g4/M...
# 4              18    5.0  ['https://dimg04.c-ctrip.com/images/fd/tg/g3/M...
# ..            ...    ...                                                ...
# 587             0    3.0                                                 []
# 588             0    3.0                                                 []
# 589             2    1.0                                                 []
# 590             3    1.0                                                 []
# 591             0    5.0                                                 []
#
# [592 rows x 8 columns]

# %%
# prompt: ["Publish Time"] 컬럼에서 发布点评을 삭제하고 2017-05-18 같은 형식으로 표현

import pandas as pd

df = pd.read_csv('comments_60_pages.csv')

# Remove "发布点评" and format the date
def clean_publish_time(time_str):
    if isinstance(time_str, str) and "发布点评" in time_str:
        return time_str.replace("发布点评", "").strip()
    return time_str

df["Publish Time"] = df["Publish Time"].apply(clean_publish_time)

# %%
df
# Out:
#      Comment ID            User Nick  \
# 0     107267523               远行-遇见你
# 1      92580773          132****2066
# 2      71514243                 阿断断断
# 3      70847520          chri****_17
# 4      69665032              1990有43
# ..          ...                  ...
# 587    89126117                 geer
# 588    79451123  Little_monster_2018
# 589   141595045          137****5124
# 590    99461898                 AA杨素
# 591   200329124                   친구
#
#                                             User Image  \
# 0    https://dimg04.c-ctrip.com/images/0Z80g1200084...
# 1    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 2    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 3    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 4    https://dimg04.c-ctrip.com/images/Z80j17000001...
# ..                                                 ...
# 587  https://dimg04.c-ctrip.com/images/Z80i0w000000...
# 588  https://dimg04.c-ctrip.com/images/Z8090o000000...
# 589  https://dimg04.c-ctrip.com/images/Z80o18000001...
# 590  https://dimg04.c-ctrip.com/images/Z80t14000000...
# 591  https://dimg04.c-ctrip.com/images/Z80o18000001...
#
#                                        Comment Content Publish Time  \
# 0    登上汉拿山顶可以远眺整个济州市，从城板岳线路上然后观音寺线路下，一路上风景美不胜收，映入眼眸...   2017-05-18
# 1    在公车上看到一群老人穿着运动装，下车后跟着他们走就找到登山的路了，建议一定要穿专门的登山鞋，...   2016-12-01
# 2    汉拿山，世遗，免费。问询处提供中文地图，一位中文很好的大姐把每段路用时多少公交信息都帮忙写在...   2016-03-13
# 3    我们是2月份去的，山脚下就全是雪，可见山上的积雪有多厚。选择的是城板岳路线，单程9.6km，...   2016-02-14
# 4    极少有中国人，即便有1.不到顶2.装备不专业。所以如果爬，1.装备一定要专业（韩国人都巨专业...   2016-01-12
# ..                                                 ...          ...
# 587                                    一般吧，反正是座山，不算壮观。   2016-10-02
# 588            我们来到汉拿山公园的时候正好是阴天 山上雾蒙蒙的 也没有什么可看 能见度特别低   2016-07-01
# 589  小伙伴们，给大家发红包喽！人人可领，领完就能用。祝大家领取的红包金额大大大！#吱口令#长按复...   2017-11-06
# 590                                  携程个垃圾还在销售韩国旅游产品呀？   2017-03-18
# 591                             在下雪的汉拿山山顶感受到的成就感。最好的礼物   2024-12-25
#
#      Useful Count  Score                                             Images
# 0              11    5.0  ['https://dimg04.c-ctrip.com/images/100e0g0000...
# 1              25    5.0  ['https://dimg04.c-ctrip.com/images/100v0b0000...
# 2              85    5.0  ['https://dimg04.c-ctrip.com/images/fd/tg/g4/M...
# 3              25    5.0  ['https://dimg04.c-ctrip.com/images/fd/tg/g4/M...
# 4              18    5.0  ['https://dimg04.c-ctrip.com/images/fd/tg/g3/M...
# ..            ...    ...                                                ...
# 587             0    3.0                                                 []
# 588             0    3.0                                                 []
# 589             2    1.0                                                 []
# 590             3    1.0                                                 []
# 591             0    5.0                                                 []
#
# [592 rows x 8 columns]

# %%
# prompt: ["Comment ID"] 컬럼 삭제

df = df.drop(columns=["Comment ID"])

# %%
df
# Out:
#                User Nick                                    Comment Content  \
# 0                 远行-遇见你  登上汉拿山顶可以远眺整个济州市，从城板岳线路上然后观音寺线路下，一路上风景美不胜收，映入眼眸...
# 1            132****2066  在公车上看到一群老人穿着运动装，下车后跟着他们走就找到登山的路了，建议一定要穿专门的登山鞋，...
# 2                   阿断断断  汉拿山，世遗，免费。问询处提供中文地图，一位中文很好的大姐把每段路用时多少公交信息都帮忙写在...
# 3            chri****_17  我们是2月份去的，山脚下就全是雪，可见山上的积雪有多厚。选择的是城板岳路线，单程9.6km，...
# 4                1990有43  极少有中国人，即便有1.不到顶2.装备不专业。所以如果爬，1.装备一定要专业（韩国人都巨专业...
# ..                   ...                                                ...
# 587                 geer                                    一般吧，反正是座山，不算壮观。
# 588  Little_monster_2018            我们来到汉拿山公园的时候正好是阴天 山上雾蒙蒙的 也没有什么可看 能见度特别低
# 589          137****5124  小伙伴们，给大家发红包喽！人人可领，领完就能用。祝大家领取的红包金额大大大！#吱口令#长按复...
# 590                 AA杨素                                  携程个垃圾还在销售韩国旅游产品呀？
# 591                   친구                             在下雪的汉拿山山顶感受到的成就感。最好的礼物
#
#     Publish Time  Useful Count  Score
# 0     2017-05-18            11    5.0
# 1     2016-12-01            25    5.0
# 2     2016-03-13            85    5.0
# 3     2016-02-14            25    5.0
# 4     2016-01-12            18    5.0
# ..           ...           ...    ...
# 587   2016-10-02             0    3.0
# 588   2016-07-01             0    3.0
# 589   2017-11-06             2    1.0
# 590   2017-03-18             3    1.0
# 591   2024-12-25             0    5.0
#
# [592 rows x 5 columns]

# %%
# prompt: ["Publish Time"]을 날짜 데이터형식으로 변환

import pandas as pd

df = pd.read_csv('comments_60_pages.csv')

# Remove "发布点评" and format the date
def clean_publish_time(time_str):
    if isinstance(time_str, str) and "发布点评" in time_str:
        return time_str.replace("发布点评", "").strip()
    return time_str

df["Publish Time"] = df["Publish Time"].apply(clean_publish_time)

# Convert to datetime, handling errors
df["Publish Time"] = pd.to_datetime(df["Publish Time"], errors='coerce')

df
# Out:
#      Comment ID            User Nick  \
# 0     107267523               远行-遇见你
# 1      92580773          132****2066
# 2      71514243                 阿断断断
# 3      70847520          chri****_17
# 4      69665032              1990有43
# ..          ...                  ...
# 587    89126117                 geer
# 588    79451123  Little_monster_2018
# 589   141595045          137****5124
# 590    99461898                 AA杨素
# 591   200329124                   친구
#
#                                             User Image  \
# 0    https://dimg04.c-ctrip.com/images/0Z80g1200084...
# 1    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 2    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 3    https://dimg04.c-ctrip.com/images/fd/headphoto...
# 4    https://dimg04.c-ctrip.com/images/Z80j17000001...
# ..                                                 ...
# 587  https://dimg04.c-ctrip.com/images/Z80i0w000000...
# 588  https://dimg04.c-ctrip.com/images/Z8090o000000...
# 589  https://dimg04.c-ctrip.com/images/Z80o18000001...
# 590  https://dimg04.c-ctrip.com/images/Z80t14000000...
# 591  https://dimg04.c-ctrip.com/images/Z80o18000001...
#
#                                        Comment Content Publish Time  \
# 0    登上汉拿山顶可以远眺整个济州市，从城板岳线路上然后观音寺线路下，一路上风景美不胜收，映入眼眸...   2017-05-18
# 1    在公车上看到一群老人穿着运动装，下车后跟着他们走就找到登山的路了，建议一定要穿专门的登山鞋，...   2016-12-01
# 2    汉拿山，世遗，免费。问询处提供中文地图，一位中文很好的大姐把每段路用时多少公交信息都帮忙写在...   2016-03-13
# 3    我们是2月份去的，山脚下就全是雪，可见山上的积雪有多厚。选择的是城板岳路线，单程9.6km，...   2016-02-14
# 4    极少有中国人，即便有1.不到顶2.装备不专业。所以如果爬，1.装备一定要专业（韩国人都巨专业...   2016-01-12
# ..                                                 ...          ...
# 587                                    一般吧，反正是座山，不算壮观。   2016-10-02
# 588            我们来到汉拿山公园的时候正好是阴天 山上雾蒙蒙的 也没有什么可看 能见度特别低   2016-07-01
# 589  小伙伴们，给大家发红包喽！人人可领，领完就能用。祝大家领取的红包金额大大大！#吱口令#长按复...   2017-11-06
# 590                                  携程个垃圾还在销售韩国旅游产品呀？   2017-03-18
# 591                             在下雪的汉拿山山顶感受到的成就感。最好的礼物   2024-12-25
#
#      Useful Count  Score                                             Images
# 0              11    5.0  ['https://dimg04.c-ctrip.com/images/100e0g0000...
# 1              25    5.0  ['https://dimg04.c-ctrip.com/images/100v0b0000...
# 2              85    5.0  ['https://dimg04.c-ctrip.com/images/fd/tg/g4/M...
# 3              25    5.0  ['https://dimg04.c-ctrip.com/images/fd/tg/g4/M...
# 4              18    5.0  ['https://dimg04.c-ctrip.com/images/fd/tg/g3/M...
# ..            ...    ...                                                ...
# 587             0    3.0                                                 []
# 588             0    3.0                                                 []
# 589             2    1.0                                                 []
# 590             3    1.0                                                 []
# 591             0    5.0                                                 []
#
# [592 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Comment ID       592 non-null    int64
#  1   User Nick        588 non-null    object
#  2   User Image       588 non-null    object
#  3   Comment Content  592 non-null    object
#  4   Publish Time     592 non-null    datetime64[ns]
#  5   Useful Count     592 non-null    int64
#  6   Score            592 non-null    float64
#  7   Images           592 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 37.1+ KB

# %%
df.drop(columns = ["Comment ID","User Image","Images"], inplace = True,axis = 1)

# %%
df
# Out:
#                User Nick                                    Comment Content  \
# 0                 远行-遇见你  登上汉拿山顶可以远眺整个济州市，从城板岳线路上然后观音寺线路下，一路上风景美不胜收，映入眼眸...
# 1            132****2066  在公车上看到一群老人穿着运动装，下车后跟着他们走就找到登山的路了，建议一定要穿专门的登山鞋，...
# 2                   阿断断断  汉拿山，世遗，免费。问询处提供中文地图，一位中文很好的大姐把每段路用时多少公交信息都帮忙写在...
# 3            chri****_17  我们是2月份去的，山脚下就全是雪，可见山上的积雪有多厚。选择的是城板岳路线，单程9.6km，...
# 4                1990有43  极少有中国人，即便有1.不到顶2.装备不专业。所以如果爬，1.装备一定要专业（韩国人都巨专业...
# ..                   ...                                                ...
# 587                 geer                                    一般吧，反正是座山，不算壮观。
# 588  Little_monster_2018            我们来到汉拿山公园的时候正好是阴天 山上雾蒙蒙的 也没有什么可看 能见度特别低
# 589          137****5124  小伙伴们，给大家发红包喽！人人可领，领完就能用。祝大家领取的红包金额大大大！#吱口令#长按复...
# 590                 AA杨素                                  携程个垃圾还在销售韩国旅游产品呀？
# 591                   친구                             在下雪的汉拿山山顶感受到的成就感。最好的礼物
#
#     Publish Time  Useful Count  Score
# 0     2017-05-18            11    5.0
# 1     2016-12-01            25    5.0
# 2     2016-03-13            85    5.0
# 3     2016-02-14            25    5.0
# 4     2016-01-12            18    5.0
# ..           ...           ...    ...
# 587   2016-10-02             0    3.0
# 588   2016-07-01             0    3.0
# 589   2017-11-06             2    1.0
# 590   2017-03-18             3    1.0
# 591   2024-12-25             0    5.0
#
# [592 rows x 5 columns]

# %%
# prompt: df['Comment Content'] 를 TF-IDF로 5개의 주제로 토픽모델링을 하고 각 토픽별 주요 키워드와 가중치 20개씩 추출

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Assuming 'df' is your DataFrame and 'Comment Content' is the column
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=1000, stop_words='english') # Adjust parameters as needed
tfidf = vectorizer.fit_transform(df['Comment Content'].astype(str))

lda = LatentDirichletAllocation(n_components=5, random_state=42) # 5 topics
lda.fit(tfidf)

feature_names = vectorizer.get_feature_names_out()

for topic_idx, topic in enumerate(lda.components_):
    print(f"Topic {topic_idx + 1}:")
    top_keywords_indices = topic.argsort()[:-21:-1]  # Get top 20 keywords
    top_keywords = [feature_names[i] for i in top_keywords_indices]
    top_weights = topic[top_keywords_indices]

    for keyword, weight in zip(top_keywords, top_weights):
        print(f"  - {keyword}: {weight:.3f}") # Print keywords and weights
    print("-" * 20)
# Out:
# Topic 1:
#   - 风景如画: 4.200
#   - 很大的公园: 2.890
#   - 景色宜人: 2.682
#   - 不错: 2.434
#   - 景色不错: 2.206
#   - 游客不多: 2.200
#   - 无门票: 2.200
#   - 7公里: 1.923
#   - 白鹿潭: 1.922
#   - 人也不多: 1.907
#   - 很喜欢: 1.907
#   - 韩国最高的山峰: 1.907
#   - 冬天去的: 1.907
#   - 汉拿山是韩国最高的山: 1.907
#   - 汉拿山是韩国最高峰: 1.876
#   - 雪很厚: 1.777
#   - 风景非常漂亮: 1.630
#   - 景色非常好: 1.627
#   - 空气超好的: 1.614
#   - 值得去的地方: 1.511
# --------------------
# Topic 2:
#   - 950米: 4.882
#   - 海拔高度为1: 3.939
#   - 景色一般: 3.552
#   - 很美: 3.473
#   - 在济州岛任何地方都能看见: 3.470
#   - 汉拿山意为: 3.430
#   - 能拿下银河的高山: 3.430
#   - 汉拿山是韩国三大名山之一: 3.314
#   - 非常值得一去的地方: 3.041
#   - 风景不错: 2.805
#   - 是韩国最高的山: 2.699
#   - 山顶上有约25: 2.605
#   - 周围有360多个大小因火山爆发形成的小火山: 2.605
#   - 是座神秘莫测的山: 2.557
#   - 季节变化山色也变: 2.557
#   - 看的角度不同山势就不同: 2.312
#   - 一定要去: 2.200
#   - 汉拿山是济州岛的名山: 2.200
#   - 000年前因火山爆发而形成的直径500米的火山湖白鹿潭: 2.142
#   - 韩国第一高峰: 1.913
# --------------------
# Topic 3:
#   - 汉拿山: 8.761
#   - 景色很美: 7.017
#   - 空气清新: 5.211
#   - 值得一去: 4.640
#   - 海拔1950米: 3.992
#   - 空气好: 3.603
#   - 免费: 3.194
#   - 不要门票: 2.992
#   - 汉拿山是韩国第一高峰: 2.917
#   - 哈哈: 2.783
#   - 漂亮: 2.775
#   - 人很少: 2.639
#   - 汉拿山是韩国的第一高峰: 2.200
#   - 位于济州岛中部: 2.200
#   - 风景秀丽: 2.127
#   - 无需门票: 1.956
#   - 空气很好: 1.934
#   - 环境很好: 1.923
#   - 雪景很美: 1.907
#   - 很好: 1.802
# --------------------
# Topic 4:
#   - 没有门票: 2.890
#   - 景色非常漂亮: 2.722
#   - 汉拿山是济州岛最有名的山峰: 2.441
#   - 不需要门票: 2.214
#   - 门票免费: 2.213
#   - 风景还是不错的: 2.200
#   - 很舒服: 2.200
#   - 很值得去: 2.200
#   - 汉拿山很值得一爬: 2.200
#   - 满眼的绿色: 1.934
#   - 这里面面积很大: 1.932
#   - 很适合来登山: 1.932
#   - 一般都是当地人比较多: 1.932
#   - 山上云雾缭绕: 1.907
#   - 灵室下: 1.907
#   - 从济州岛的任何地方都可以看到汉拿山: 1.907
#   - 风景优美: 1.907
#   - 终于看到传说中的火焰山: 1.781
#   - 老公带着我一路爬上了最高点: 1.781
#   - 山上风景秀丽: 1.669
# --------------------
# Topic 5:
#   - 还不错: 5.200
#   - 空气很新鲜: 3.200
#   - 空气质量好: 2.889
#   - 推荐: 2.225
#   - 值得一去的地方: 2.200
#   - 御里牧下山: 2.200
#   - 特别的漂亮: 2.200
#   - 非常漂亮: 2.200
#   - 风景很好: 2.200
#   - amp: 2.181
#   - 又称瀛州山: 1.978
#   - 是韩国第一高峰: 1.926
#   - 也是一座休眠火山: 1.732
#   - 冰爪: 1.542
#   - 景色不错: 1.535
#   - quot: 1.212
#   - 风景很美: 1.206
#   - 值得: 1.206
#   - 还是很累的: 1.205
#   - 免费的景点: 1.205
# --------------------

# %%
# prompt: df['combined']를 통해 5개로 군집화 하고 마지막컬럼에 군집값을 넣어주고 각 군집별로 상위 키워드 20개와 가중치 출력, 각 군집에 할당된 데이터 수도 함께 표시

from sklearn.cluster import KMeans

# Assuming 'df' is your DataFrame and 'combined' is the column you want to use for clustering
kmeans = KMeans(n_clusters=5, random_state=42)  # 5 clusters
df['cluster'] = kmeans.fit_predict(df[['Score', 'Useful Count']])

# Calculate cluster sizes
cluster_sizes = df['cluster'].value_counts()

# Display cluster sizes
print("Cluster Sizes:")
print(cluster_sizes)
print("-" * 20)

# Get top keywords for each cluster
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=1000, stop_words='english')
tfidf = vectorizer.fit_transform(df['Comment Content'].astype(str))
feature_names = vectorizer.get_feature_names_out()

for cluster_num in range(5):
    cluster_data = df[df['cluster'] == cluster_num]['Comment Content'].astype(str)
    cluster_tfidf = vectorizer.transform(cluster_data)

    # Sum tf-idf values for each word across all documents in the cluster
    cluster_tfidf_sum = cluster_tfidf.sum(axis=0)

    # Get top 20 keywords and their weights
    top_keywords_indices = cluster_tfidf_sum.argsort()[:-21:-1]
    top_keywords = [feature_names[i] for i in top_keywords_indices]
    top_weights = cluster_tfidf_sum[0, top_keywords_indices].A1  # Convert sparse matrix to array

    print(f"Top Keywords for Cluster {cluster_num + 1}:")
    for keyword, weight in zip(top_keywords, top_weights):
        print(f"  - {keyword}: {weight:.3f}")
    print("-" * 20)
# Out:
# Cluster Sizes:
# cluster
# 0    557
# 3     20
# 4     10
# 1      4
# 2      1
# Name: count, dtype: int64
# --------------------
# Top Keywords for Cluster 1:
#   - [['灵室下' '御乘生岳最富代表性' '5公里' '体力不好最好打车到车站' '灵室路线终点离公交车站有2' '且全是很陡的盘山下坡'
#   '去之前在汉拿山博物院里看了关于汉拿山的纪录片' '旅行团也很喜欢去' '不然容易滑倒' '冬季登山一定得带上冰爪' '其中土赤岳'
#   '周围的侧火山多达360个之多' '风化侵蚀等地形地貌' '有火山' '砂罗岳' '安排的时间有限我们只爬到半山腰处就急着往回走下山了'
#   '由于是跟团的行程' '以后有机会在春天的时候再来爬爬汉拿山' '观音寺两条线路' '但能抵达顶峰白鹿潭的只有城板岳'
#   '御里牧是几条线路中最容易爬的' '部分原始不平的石块路' '全程山路部分用木板铺路' '一路基本上都是高低不平大小不一的石头路'
#   '走起来有点艰辛' '公交也非常方便' '就最原始的目的就是想爬汉拿山' '在北京经常爬山' '值得一来' '山真的是非常非常高'
#   '累死我了' '发现自己低估山的难度' '但是风景极好' '但是来了以后' '所以眨眼就到了' '所以没把汉拿山当回事' '当初来济州岛'
#   '路非常非常长' '这边的司机车都是开的飞快的' '一路风光很美' '回头从御里牧下山' '再向顿乃克方向走到主峰山脚下'
#   '一心希望到顶能看到美景' '登顶拍照证明下山后可以用1000韩币办一个证书' '结果白茫茫一片雾' '我是从灵室上山到威势岳庇护所'
#   '看到一个个中国人来到这里看美景' '可见汉拿山是韩国很经典的景点啦' '汉拿山就是韩国的一切' '建议早点上山'
#   '所以大家一定要计划好时间' '所以很难爬' '如果中午12点前没有到这处' '特别是最后一段' '没有进行铺垫' '是山原来的石头'
#   '此段汉拿山有一个休息区叫金达莱' '12点后是无法再往上爬了' '不像中国的山一样都有台阶' '冬季的最后登山时间是早上10点'
#   '漂亮干净整洁' '对于没有看过太多雪的南方人来说冬日去看看雪是最好的' '秋天的红叶' '前来此地观赏春天的杜鹃花' '夏天的高山植物'
#   '汉拿山国家公园为一座拥有夏天开满花朵火山湖的秀丽之山' '与冬天的雪景之登山客络绎不绝' '问询处提供中文地图'
#   '一位中文很好的大姐把每段路用时多少公交信息都帮忙写在地图上感动哭' '登山杖' '夏天热的要命' '非常好' '冰爪'
#   '有着很高的学术价值' '山顶上是火山喷发形成的白鹿潭' '这座休眠火山有着十分独特壮观的景色' '是韩国最高的山峰'
#   '随海拔升高垂直分布着从亚热带到寒带的数千种动植物' '汉拿山位于济州岛中央' '呈东西走向' '南山陡峭而北山平缓' '粉紫色的晚霞'
#   '很美很美' '是来济州岛一定要来的地方' '美到窒息' '汉拿山自然风光很美' '一定要记得带能量棒不然帕到一半就没力气了' '城板岳'
#   '汉拿山分布着各种植物' '河川' '冰缘' '湿地' '意思是高得可抓住银河' '海拔高度为1950米' '在汉拿山医院门口'
#   '可以到达御里牧登山口' '它有个好听的名字叫' '汉拿山2007年被列入世界自然遗产区域' '山顶是火山湖'
#   '山顶是因火山爆发而形成的火山湖' '坐740' '很值得去' '御里牧下山' '汉拿山很好玩儿' '郁郁葱葱'
#   '春秋两季是汉拿山的黄金旅游季节' '汉拿山在济州岛中部' '山上云雾缭绕' '没有缆车' '济州岛必游景点之一' '满眼的绿色'
#   '建议赶上早上8点那趟车' '如果想要回程也能搭上公交车的话' 'quot' '最早一班车是6点半' '终于看到传说中的火焰山'
#   '老公带着我一路爬上了最高点' '可以选择不能登顶的灵室和御里牧线路' '整个汉拿山景区都是免门票的' '如果希望轻松一些' '5小时'
#   '济州岛的标志性景点' '单程9' '是韩国第一高峰' '蓝天白云' '值得一游' '值得去的地方' '很开心' '空气不错' '白云'
#   '这处公园的环境也是蛮好的' '有好几个登山口' '空气超好的' '蓝天' '汉拿山国立公园也是一座很特别的建筑了' '灵室'
#   '风景非常漂亮' '景色非常好' '是代表济州岛的名山' '汉拿山巍然耸立于济州岛的中部' '山上风景秀丽' '标志性的景点'
#   '爬山真的好累' '000年前因火山爆发而形成的直径500米的火山湖白鹿潭' '风景很美' '值得' '堪称一个生态王国' '灵室下山'
#   '雪很厚' '景色美' '很好' '植被茂盛' '汉拿山是韩国最高峰' '是南韩最高的山' '汉拿山是韩国最高的山' '很喜欢'
#   '还是很累的' '风景优美' '人也不多' '蓝蓝的天' '特别喜欢' '一年四季' '从济州岛的任何地方都可以看到汉拿山' '雪景很美'
#   '山上风很大' '冬天去的' '环境舒适' '韩国最高的山峰' '白鹿潭' '7公里' '环境很好' '这里面面积很大'
#   '一般都是当地人比较多' '很适合来登山' '空气很好' '免费的景点' '山不是很高' '也是一座休眠火山' '无需门票' '哈哈'
#   '风景秀丽' '山顶上有约25' '周围有360多个大小因火山爆发形成的小火山' 'amp' '风景很好' '无门票' '特别的漂亮'
#   '风景还是不错的' '汉拿山是韩国的第一高峰' '汉拿山是济州岛的名山' '游客不多' '一定要去' '很舒服' '非常漂亮'
#   '汉拿山很值得一爬' '值得一去的地方' '位于济州岛中部' '景色非常漂亮' '看的角度不同山势就不同' '非常值得一去的地方'
#   '是座神秘莫测的山' '季节变化山色也变' '又称瀛州山' '人很少' '景色宜人' '不需要门票' '是韩国最高的山' '漂亮'
#   '门票免费' '推荐' '很美' '风景不错' '免费' '韩国第一高峰' '很大的公园' '没有门票' '空气质量好' '不要门票'
#   '汉拿山意为' '能拿下银河的高山' '不错' '汉拿山是济州岛最有名的山峰' '空气很新鲜' '汉拿山是韩国第一高峰'
#   '汉拿山是韩国三大名山之一' '在济州岛任何地方都能看见' '景色一般' '空气好' '海拔高度为1' '风景如画' '值得一去'
#   '海拔1950米' '景色不错' '950米' '还不错' '空气清新' '景色很美' '汉拿山']]: 0.000
# --------------------
# Top Keywords for Cluster 2:
#   - [['000年前因火山爆发而形成的直径500米的火山湖白鹿潭' '汉拿山是韩国三大名山之一' '汉拿山是韩国最高峰' '汉拿山是韩国最高的山'
#   '汉拿山是韩国的第一高峰' '汉拿山是韩国第一高峰' '汉拿山自然风光很美' '没有缆车' '没有进行铺垫' '没有门票' '河川'
#   '济州岛必游景点之一' '济州岛的标志性景点' '海拔1950米' '海拔高度为1' '海拔高度为1950米' '游客不多' '湿地'
#   '满眼的绿色' '漂亮' '漂亮干净整洁' '灵室' '灵室下' '灵室下山' '灵室路线终点离公交车站有2' '爬山真的好累'
#   '汉拿山是济州岛的名山' '汉拿山意为' '汉拿山很好玩儿' '汉拿山很值得一爬' '是来济州岛一定要来的地方' '是韩国最高的山'
#   '是韩国最高的山峰' '是韩国第一高峰' '景色一般' '景色不错' '景色宜人' '景色很美' '景色美' '景色非常好' '景色非常漂亮'
#   '有好几个登山口' '特别喜欢' '有火山' '标志性的景点' '植被茂盛' '此段汉拿山有一个休息区叫金达莱' '汉拿山'
#   '汉拿山2007年被列入世界自然遗产区域' '汉拿山位于济州岛中央' '汉拿山分布着各种植物'
#   '汉拿山国家公园为一座拥有夏天开满花朵火山湖的秀丽之山' '汉拿山国立公园也是一座很特别的建筑了' '汉拿山在济州岛中部'
#   '汉拿山就是韩国的一切' '汉拿山巍然耸立于济州岛的中部' '有着很高的学术价值' '是座神秘莫测的山' '特别是最后一段' '环境很好'
#   '还不错' '还是很累的' '这处公园的环境也是蛮好的' '这座休眠火山有着十分独特壮观的景色' '这边的司机车都是开的飞快的'
#   '这里面面积很大' '郁郁葱葱' '部分原始不平的石块路' '门票免费' '问询处提供中文地图'
#   '随海拔升高垂直分布着从亚热带到寒带的数千种动植物' '雪很厚' '雪景很美' '非常值得一去的地方' '非常好' '非常漂亮'
#   '韩国最高的山峰' '韩国第一高峰' '风化侵蚀等地形地貌' '风景不错' '风景优美' '风景如画' '风景很好' '风景很美'
#   '风景秀丽' '路非常非常长' '走起来有点艰辛' '观音寺两条线路' '蓝蓝的天' '环境舒适' '由于是跟团的行程' '登山杖'
#   '登顶拍照证明下山后可以用1000韩币办一个证书' '白云' '白鹿潭' '看到一个个中国人来到这里看美景' '看的角度不同山势就不同'
#   '砂罗岳' '秋天的红叶' '空气不错' '空气好' '特别的漂亮' '空气很好' '空气清新' '空气质量好' '空气超好的'
#   '粉紫色的晚霞' '累死我了' '终于看到传说中的火焰山' '结果白茫茫一片雾' '美到窒息' '老公带着我一路爬上了最高点'
#   '能拿下银河的高山' '蓝天' '蓝天白云' '空气很新鲜' '风景还是不错的' '是山原来的石头' '是代表济州岛的名山'
#   '位于济州岛中部' '体力不好最好打车到车站' '值得' '值得一去' '值得一去的地方' '值得一来' '值得一游' '值得去的地方'
#   '免费' '免费的景点' '全程山路部分用木板铺路' '公交也非常方便' '其中土赤岳' '再向顿乃克方向走到主峰山脚下' '冬天去的'
#   '冰爪' '冰缘' '前来此地观赏春天的杜鹃花' '单程9' '南山陡峭而北山平缓' '去之前在汉拿山博物院里看了关于汉拿山的纪录片'
#   '又称瀛州山' '发现自己低估山的难度' '可以选择不能登顶的灵室和御里牧线路' '可见汉拿山是韩国很经典的景点啦'
#   '但能抵达顶峰白鹿潭的只有城板岳' '是南韩最高的山' '但是风景极好' '以后有机会在春天的时候再来爬爬汉拿山'
#   '12点后是无法再往上爬了' '5公里' '5小时' '7公里' '950米' 'amp' 'quot'
#   '一位中文很好的大姐把每段路用时多少公交信息都帮忙写在地图上感动哭' '一定要去' '一定要记得带能量棒不然帕到一半就没力气了' '一年四季'
#   '一心希望到顶能看到美景' '一般都是当地人比较多' '一路基本上都是高低不平大小不一的石头路' '一路风光很美'
#   '不像中国的山一样都有台阶' '不要门票' '不错' '不需要门票' '与冬天的雪景之登山客络绎不绝' '且全是很陡的盘山下坡'
#   '也是一座休眠火山' '人也不多' '人很少' '从济州岛的任何地方都可以看到汉拿山' '但是来了以后'
#   '周围有360多个大小因火山爆发形成的小火山' '呈东西走向' '哈哈' '建议早点上山' '当初来济州岛' '很值得去' '很喜欢'
#   '很大的公园' '很好' '很开心' '很美' '很美很美' '很舒服' '很适合来登山' '御乘生岳最富代表性'
#   '周围的侧火山多达360个之多' '御里牧下山' '意思是高得可抓住银河' '我是从灵室上山到威势岳庇护所' '所以大家一定要计划好时间'
#   '所以很难爬' '所以没把汉拿山当回事' '所以眨眼就到了' '推荐' '整个汉拿山景区都是免门票的' '旅行团也很喜欢去' '无门票'
#   '无需门票' '春秋两季是汉拿山的黄金旅游季节' '御里牧是几条线路中最容易爬的' '山顶是因火山爆发而形成的火山湖' '山顶是火山湖'
#   '风景非常漂亮' '城板岳' '堪称一个生态王国' '夏天热的要命' '夏天的高山植物' '如果中午12点前没有到这处' '如果希望轻松一些'
#   '山顶上有约25' '在济州岛任何地方都能看见' '季节变化山色也变' '它有个好听的名字叫' '在北京经常爬山' '回头从御里牧下山'
#   '就最原始的目的就是想爬汉拿山' '山上云雾缭绕' '山上风很大' '山上风景秀丽' '山不是很高' '山真的是非常非常高'
#   '山顶上是火山喷发形成的白鹿潭' '安排的时间有限我们只爬到半山腰处就急着往回走下山了' '如果想要回程也能搭上公交车的话'
#   '在汉拿山医院门口' '最早一班车是6点半' '建议赶上早上8点那趟车' '坐740' '可以到达御里牧登山口' '冬季登山一定得带上冰爪'
#   '不然容易滑倒' '冬季的最后登山时间是早上10点' '汉拿山是济州岛最有名的山峰' '对于没有看过太多雪的南方人来说冬日去看看雪是最好的']]: 0.000
# --------------------
# Top Keywords for Cluster 3:
#   - [['000年前因火山爆发而形成的直径500米的火山湖白鹿潭' '汉拿山意为' '汉拿山是济州岛最有名的山峰' '汉拿山是济州岛的名山'
#   '汉拿山是韩国三大名山之一' '汉拿山是韩国最高峰' '汉拿山是韩国最高的山' '汉拿山是韩国的第一高峰' '汉拿山是韩国第一高峰'
#   '汉拿山自然风光很美' '没有进行铺垫' '没有门票' '河川' '济州岛必游景点之一' '济州岛的标志性景点' '海拔1950米'
#   '海拔高度为1' '海拔高度为1950米' '游客不多' '湿地' '满眼的绿色' '漂亮' '漂亮干净整洁' '灵室' '灵室下'
#   '灵室下山' '汉拿山很好玩儿' '爬山真的好累' '汉拿山很值得一爬' '汉拿山就是韩国的一切' '是座神秘莫测的山'
#   '是来济州岛一定要来的地方' '是韩国最高的山' '是韩国最高的山峰' '是韩国第一高峰' '景色一般' '景色不错' '景色宜人'
#   '景色很美' '景色美' '景色非常好' '景色非常漂亮' '最早一班车是6点半' '有好几个登山口' '有火山' '有着很高的学术价值'
#   '标志性的景点' '植被茂盛' '此段汉拿山有一个休息区叫金达莱' '汉拿山2007年被列入世界自然遗产区域' '汉拿山位于济州岛中央'
#   '汉拿山分布着各种植物' '汉拿山国家公园为一座拥有夏天开满花朵火山湖的秀丽之山' '汉拿山国立公园也是一座很特别的建筑了'
#   '汉拿山在济州岛中部' '汉拿山巍然耸立于济州岛的中部' '特别喜欢' '特别是最后一段' '特别的漂亮' '路非常非常长' '还不错'
#   '还是很累的' '这处公园的环境也是蛮好的' '这座休眠火山有着十分独特壮观的景色' '这边的司机车都是开的飞快的' '这里面面积很大'
#   '郁郁葱葱' '部分原始不平的石块路' '门票免费' '随海拔升高垂直分布着从亚热带到寒带的数千种动植物' '雪很厚' '雪景很美'
#   '非常值得一去的地方' '非常好' '非常漂亮' '韩国最高的山峰' '韩国第一高峰' '风化侵蚀等地形地貌' '风景不错' '风景优美'
#   '风景如画' '风景很好' '风景很美' '风景秀丽' '走起来有点艰辛' '观音寺两条线路' '蓝蓝的天' '蓝天白云' '环境很好'
#   '环境舒适' '由于是跟团的行程' '登山杖' '登顶拍照证明下山后可以用1000韩币办一个证书' '白云' '白鹿潭'
#   '看到一个个中国人来到这里看美景' '看的角度不同山势就不同' '砂罗岳' '秋天的红叶' '空气不错' '风景还是不错的' '空气好'
#   '空气很新鲜' '空气清新' '空气质量好' '空气超好的' '粉紫色的晚霞' '累死我了' '终于看到传说中的火焰山' '结果白茫茫一片雾'
#   '美到窒息' '老公带着我一路爬上了最高点' '能拿下银河的高山' '蓝天' '空气很好' '是南韩最高的山' '是山原来的石头'
#   '春秋两季是汉拿山的黄金旅游季节' '值得一去' '值得一去的地方' '值得一来' '值得一游' '值得去的地方' '免费的景点'
#   '全程山路部分用木板铺路' '公交也非常方便' '其中土赤岳' '再向顿乃克方向走到主峰山脚下' '冬天去的' '值得'
#   '冬季登山一定得带上冰爪' '冰爪' '冰缘' '前来此地观赏春天的杜鹃花' '单程9' '南山陡峭而北山平缓'
#   '去之前在汉拿山博物院里看了关于汉拿山的纪录片' '又称瀛州山' '发现自己低估山的难度' '可以到达御里牧登山口'
#   '可以选择不能登顶的灵室和御里牧线路' '是代表济州岛的名山' '冬季的最后登山时间是早上10点' '位于济州岛中部'
#   '但能抵达顶峰白鹿潭的只有城板岳' '但是风景极好' '12点后是无法再往上爬了' '5小时' '7公里' '950米' 'amp'
#   'quot' '一定要去' '一定要记得带能量棒不然帕到一半就没力气了' '一年四季' '一心希望到顶能看到美景' '一般都是当地人比较多'
#   '一路基本上都是高低不平大小不一的石头路' '一路风光很美' '不像中国的山一样都有台阶' '不然容易滑倒' '不要门票' '不错'
#   '不需要门票' '与冬天的雪景之登山客络绎不绝' '也是一座休眠火山' '人也不多' '人很少' '从济州岛的任何地方都可以看到汉拿山'
#   '以后有机会在春天的时候再来爬爬汉拿山' '但是来了以后' '呈东西走向' '周围有360多个大小因火山爆发形成的小火山'
#   '可见汉拿山是韩国很经典的景点啦' '哈哈' '建议赶上早上8点那趟车' '当初来济州岛' '很值得去' '很喜欢' '很大的公园' '很好'
#   '很开心' '很美' '很美很美' '很舒服' '很适合来登山' '御乘生岳最富代表性' '御里牧下山' '御里牧是几条线路中最容易爬的'
#   '意思是高得可抓住银河' '我是从灵室上山到威势岳庇护所' '所以大家一定要计划好时间' '所以很难爬' '所以没把汉拿山当回事'
#   '所以眨眼就到了' '推荐' '整个汉拿山景区都是免门票的' '旅行团也很喜欢去' '无门票' '无需门票' '周围的侧火山多达360个之多'
#   '山顶是火山湖' '建议早点上山' '风景非常漂亮' '在济州岛任何地方都能看见' '坐740' '回头从御里牧下山' '城板岳'
#   '堪称一个生态王国' '夏天热的要命' '夏天的高山植物' '如果中午12点前没有到这处' '如果希望轻松一些'
#   '如果想要回程也能搭上公交车的话' '山顶是因火山爆发而形成的火山湖' '季节变化山色也变' '在汉拿山医院门口' '它有个好听的名字叫'
#   '对于没有看过太多雪的南方人来说冬日去看看雪是最好的' '就最原始的目的就是想爬汉拿山' '山上云雾缭绕' '山上风很大' '山上风景秀丽'
#   '山不是很高' '山真的是非常非常高' '山顶上是火山喷发形成的白鹿潭' '山顶上有约25'
#   '安排的时间有限我们只爬到半山腰处就急着往回走下山了' '在北京经常爬山' '汉拿山' '免费' '5公里' '灵室路线终点离公交车站有2'
#   '体力不好最好打车到车站' '没有缆车' '且全是很陡的盘山下坡' '一位中文很好的大姐把每段路用时多少公交信息都帮忙写在地图上感动哭'
#   '问询处提供中文地图']]: 0.000
# --------------------
# Top Keywords for Cluster 4:
#   - [['是山原来的石头' '汉拿山2007年被列入世界自然遗产区域' '汉拿山分布着各种植物'
#   '汉拿山国家公园为一座拥有夏天开满花朵火山湖的秀丽之山' '汉拿山国立公园也是一座很特别的建筑了' '汉拿山巍然耸立于济州岛的中部'
#   '汉拿山很值得一爬' '汉拿山是济州岛最有名的山峰' '汉拿山是济州岛的名山' '汉拿山是韩国三大名山之一' '汉拿山是韩国最高峰'
#   '汉拿山是韩国最高的山' '汉拿山是韩国的第一高峰' '汉拿山是韩国第一高峰' '汉拿山自然风光很美' '没有缆车' '没有进行铺垫'
#   '没有门票' '济州岛的标志性景点' '海拔高度为1' '海拔高度为1950米' '游客不多' '汉拿山' '此段汉拿山有一个休息区叫金达莱'
#   '植被茂盛' '标志性的景点' '所以大家一定要计划好时间' '所以很难爬' '所以没把汉拿山当回事' '所以眨眼就到了' '推荐'
#   '整个汉拿山景区都是免门票的' '无门票' '无需门票' '是代表济州岛的名山' '是南韩最高的山' '满眼的绿色' '风景还是不错的'
#   '是来济州岛一定要来的地方' '是韩国最高的山' '景色一般' '景色不错' '景色宜人' '景色很美' '景色美' '景色非常好'
#   '最早一班车是6点半' '有好几个登山口' '是座神秘莫测的山' '我是从灵室上山到威势岳庇护所' '漂亮' '灵室下山' '蓝蓝的天'
#   '走起来有点艰辛' '路非常非常长' '还不错' '还是很累的' '这处公园的环境也是蛮好的' '这边的司机车都是开的飞快的'
#   '这里面面积很大' '部分原始不平的石块路' '门票免费' '问询处提供中文地图' '雪很厚' '雪景很美' '非常漂亮' '韩国最高的山峰'
#   '风景不错' '风景优美' '风景如画' '风景很好' '风景很美' '风景秀丽' '蓝天白云' '蓝天' '美到窒息' '结果白茫茫一片雾'
#   '灵室路线终点离公交车站有2' '爬山真的好累' '特别喜欢' '特别是最后一段' '特别的漂亮' '环境很好' '环境舒适' '登山杖'
#   '登顶拍照证明下山后可以用1000韩币办一个证书' '白云' '灵室' '白鹿潭' '秋天的红叶' '空气不错' '空气好' '空气很好'
#   '空气很新鲜' '空气清新' '空气质量好' '空气超好的' '粉紫色的晚霞' '累死我了' '看的角度不同山势就不同'
#   '意思是高得可抓住银河' '风景非常漂亮' '单程9' '位于济州岛中部' '可以到达御里牧登山口' '可以选择不能登顶的灵室和御里牧线路'
#   '不像中国的山一样都有台阶' '但是风景极好' '但是来了以后' '一心希望到顶能看到美景' '哈哈' '回头从御里牧下山'
#   '在北京经常爬山' '在汉拿山医院门口' '在济州岛任何地方都能看见' '从济州岛的任何地方都可以看到汉拿山' '一般都是当地人比较多'
#   '坐740' 'quot' '人很少' '一位中文很好的大姐把每段路用时多少公交信息都帮忙写在地图上感动哭' '人也不多'
#   '发现自己低估山的难度' '体力不好最好打车到车站' '免费的景点' '值得一游' '全程山路部分用木板铺路' '公交也非常方便'
#   '一年四季' '再向顿乃克方向走到主峰山脚下' '冬天去的' '冬季登山一定得带上冰爪' '冬季的最后登山时间是早上10点' '冰爪'
#   '一定要记得带能量棒不然帕到一半就没力气了' '值得一来' '一定要去' '前来此地观赏春天的杜鹃花' '值得一去的地方' '值得一去'
#   '值得' '又称瀛州山' '免费' '值得去的地方' '夏天的高山植物' '不需要门票' '山顶是因火山爆发而形成的火山湖' '山顶是火山湖'
#   '建议早点上山' '建议赶上早上8点那趟车' '不错' '当初来济州岛' '与冬天的雪景之登山客络绎不绝' '12点后是无法再往上爬了'
#   '很喜欢' '很大的公园' '很好' '很开心' '很美' '很美很美' '很舒服' '不要门票' '夏天热的要命' '且全是很陡的盘山下坡'
#   '5公里' '一路基本上都是高低不平大小不一的石头路' '如果中午12点前没有到这处' '如果希望轻松一些'
#   '如果想要回程也能搭上公交车的话' '季节变化山色也变' '它有个好听的名字叫' 'amp' '一路风光很美' '950米'
#   '对于没有看过太多雪的南方人来说冬日去看看雪是最好的' '7公里' '就最原始的目的就是想爬汉拿山' '5小时' '山上风很大'
#   '山上风景秀丽' '山不是很高' '山真的是非常非常高' '很适合来登山' '不然容易滑倒' '海拔1950米' '堪称一个生态王国'
#   '这座休眠火山有着十分独特壮观的景色' '冰缘' '是韩国最高的山峰' '湿地' '南山陡峭而北山平缓' '河川' '汉拿山位于济州岛中央'
#   '呈东西走向' '山顶上是火山喷发形成的白鹿潭' '随海拔升高垂直分布着从亚热带到寒带的数千种动植物' '其中土赤岳' '砂罗岳' '有火山'
#   '周围的侧火山多达360个之多' '风化侵蚀等地形地貌' '观音寺两条线路' '但能抵达顶峰白鹿潭的只有城板岳'
#   '御里牧是几条线路中最容易爬的' '御乘生岳最富代表性' '春秋两季是汉拿山的黄金旅游季节' '汉拿山意为' '能拿下银河的高山'
#   '旅行团也很喜欢去' '汉拿山很好玩儿' '汉拿山就是韩国的一切' '去之前在汉拿山博物院里看了关于汉拿山的纪录片'
#   '可见汉拿山是韩国很经典的景点啦' '周围有360多个大小因火山爆发形成的小火山' '山顶上有约25'
#   '000年前因火山爆发而形成的直径500米的火山湖白鹿潭' '也是一座休眠火山' '景色非常漂亮' '是韩国第一高峰'
#   '老公带着我一路爬上了最高点' '终于看到传说中的火焰山' '以后有机会在春天的时候再来爬爬汉拿山' '由于是跟团的行程'
#   '安排的时间有限我们只爬到半山腰处就急着往回走下山了' '汉拿山在济州岛中部' '济州岛必游景点之一' '郁郁葱葱'
#   '看到一个个中国人来到这里看美景' '非常值得一去的地方' '漂亮干净整洁' '非常好' '韩国第一高峰' '灵室下' '山上云雾缭绕'
#   '城板岳' '有着很高的学术价值' '很值得去' '御里牧下山']]: 0.000
# --------------------
# Top Keywords for Cluster 5:
#   - [['000年前因火山爆发而形成的直径500米的火山湖白鹿潭' '汉拿山巍然耸立于济州岛的中部' '汉拿山很值得一爬' '汉拿山很好玩儿'
#   '汉拿山意为' '汉拿山是济州岛最有名的山峰' '汉拿山是济州岛的名山' '汉拿山是韩国三大名山之一' '汉拿山是韩国最高峰'
#   '汉拿山是韩国最高的山' '汉拿山是韩国的第一高峰' '汉拿山是韩国第一高峰' '汉拿山自然风光很美' '没有缆车' '没有进行铺垫'
#   '没有门票' '河川' '济州岛必游景点之一' '济州岛的标志性景点' '海拔1950米' '海拔高度为1' '海拔高度为1950米'
#   '游客不多' '湿地' '漂亮' '漂亮干净整洁' '汉拿山就是韩国的一切' '灵室' '汉拿山在济州岛中部'
#   '汉拿山国家公园为一座拥有夏天开满花朵火山湖的秀丽之山' '是南韩最高的山' '风景还是不错的' '是座神秘莫测的山'
#   '是来济州岛一定要来的地方' '是韩国最高的山' '是韩国最高的山峰' '是韩国第一高峰' '景色一般' '景色不错' '景色宜人'
#   '景色很美' '景色美' '景色非常好' '景色非常漂亮' '最早一班车是6点半' '有好几个登山口' '有火山' '有着很高的学术价值'
#   '标志性的景点' '植被茂盛' '此段汉拿山有一个休息区叫金达莱' '汉拿山' '汉拿山2007年被列入世界自然遗产区域'
#   '汉拿山位于济州岛中央' '汉拿山分布着各种植物' '汉拿山国立公园也是一座很特别的建筑了' '是代表济州岛的名山' '灵室下山'
#   '爬山真的好累' '路非常非常长' '还不错' '还是很累的' '这处公园的环境也是蛮好的' '这座休眠火山有着十分独特壮观的景色'
#   '这边的司机车都是开的飞快的' '这里面面积很大' '郁郁葱葱' '门票免费' '问询处提供中文地图'
#   '随海拔升高垂直分布着从亚热带到寒带的数千种动植物' '雪很厚' '雪景很美' '非常值得一去的地方' '非常好' '非常漂亮'
#   '韩国最高的山峰' '韩国第一高峰' '风化侵蚀等地形地貌' '风景不错' '风景优美' '风景如画' '风景很好' '风景很美'
#   '风景秀丽' '观音寺两条线路' '灵室路线终点离公交车站有2' '蓝蓝的天' '蓝天' '特别喜欢' '特别是最后一段' '特别的漂亮'
#   '环境很好' '环境舒适' '由于是跟团的行程' '白云' '白鹿潭' '看到一个个中国人来到这里看美景' '看的角度不同山势就不同'
#   '砂罗岳' '秋天的红叶' '空气不错' '空气好' '空气很好' '空气很新鲜' '空气清新' '空气质量好' '空气超好的'
#   '粉紫色的晚霞' '累死我了' '终于看到传说中的火焰山' '美到窒息' '老公带着我一路爬上了最高点' '能拿下银河的高山' '蓝天白云'
#   '春秋两季是汉拿山的黄金旅游季节' '是山原来的石头' '无门票' '位于济州岛中部' '体力不好最好打车到车站' '值得' '值得一去'
#   '值得一去的地方' '值得一来' '值得一游' '值得去的地方' '免费的景点' '公交也非常方便' '其中土赤岳' '冬天去的'
#   '冬季登山一定得带上冰爪' '冬季的最后登山时间是早上10点' '冰缘' '前来此地观赏春天的杜鹃花' '南山陡峭而北山平缓'
#   '去之前在汉拿山博物院里看了关于汉拿山的纪录片' '又称瀛州山' '无需门票' '可以到达御里牧登山口'
#   '可以选择不能登顶的灵室和御里牧线路' '可见汉拿山是韩国很经典的景点啦' '但能抵达顶峰白鹿潭的只有城板岳' '但是风景极好'
#   '但是来了以后' '以后有机会在春天的时候再来爬爬汉拿山' '12点后是无法再往上爬了' '5公里' '5小时' '7公里' '950米'
#   'amp' 'quot' '一位中文很好的大姐把每段路用时多少公交信息都帮忙写在地图上感动哭' '一定要去'
#   '一定要记得带能量棒不然帕到一半就没力气了' '一年四季' '呈东西走向' '一般都是当地人比较多' '不像中国的山一样都有台阶'
#   '不然容易滑倒' '不要门票' '不错' '不需要门票' '与冬天的雪景之登山客络绎不绝' '且全是很陡的盘山下坡' '也是一座休眠火山'
#   '人也不多' '人很少' '从济州岛的任何地方都可以看到汉拿山' '一路风光很美' '周围有360多个大小因火山爆发形成的小火山'
#   '发现自己低估山的难度' '周围的侧火山多达360个之多' '山真的是非常非常高' '山顶上有约25' '山顶是因火山爆发而形成的火山湖'
#   '山顶是火山湖' '建议早点上山' '建议赶上早上8点那趟车' '当初来济州岛' '很值得去' '很喜欢' '很大的公园' '很好'
#   '很开心' '山不是很高' '很美很美' '很适合来登山' '御乘生岳最富代表性' '御里牧下山' '御里牧是几条线路中最容易爬的'
#   '意思是高得可抓住银河' '所以大家一定要计划好时间' '所以很难爬' '所以没把汉拿山当回事' '所以眨眼就到了' '推荐'
#   '整个汉拿山景区都是免门票的' '旅行团也很喜欢去' '很舒服' '山上风景秀丽' '山顶上是火山喷发形成的白鹿潭' '风景非常漂亮'
#   '山上风很大' '城板岳' '夏天的高山植物' '如果中午12点前没有到这处' '如果希望轻松一些' '坐740'
#   '如果想要回程也能搭上公交车的话' '堪称一个生态王国' '季节变化山色也变' '在汉拿山医院门口' '它有个好听的名字叫'
#   '在北京经常爬山' '安排的时间有限我们只爬到半山腰处就急着往回走下山了' '对于没有看过太多雪的南方人来说冬日去看看雪是最好的'
#   '就最原始的目的就是想爬汉拿山' '山上云雾缭绕' '在济州岛任何地方都能看见' '回头从御里牧下山' '我是从灵室上山到威势岳庇护所'
#   '一心希望到顶能看到美景' '结果白茫茫一片雾' '登顶拍照证明下山后可以用1000韩币办一个证书' '部分原始不平的石块路'
#   '再向顿乃克方向走到主峰山脚下' '全程山路部分用木板铺路' '走起来有点艰辛' '一路基本上都是高低不平大小不一的石头路' '单程9'
#   '登山杖' '冰爪' '很美' '哈哈' '夏天热的要命' '满眼的绿色' '免费' '灵室下']]: 0.000
# --------------------

# %%
# prompt: 각 군집별 빈도수 시각화. plotly로 데이터 라벨 추가

import plotly.express as px

# Assuming 'cluster_sizes' is a pandas Series with cluster labels as index and counts as values
fig = px.bar(cluster_sizes,
             x=cluster_sizes.index,
             y=cluster_sizes.values,
             labels={'x':'Cluster', 'y':'Frequency'},
             title='Frequency of Each Cluster')

# Add data labels
fig.update_traces(texttemplate='%{y}', textposition='outside')  # Position the labels outside the bars

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4ef98c22-9106-4bd6-a377-55f2e87c0aa3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ef98c22-9106-4bd6-a377-55f2e87c0aa3")) {                    Plotly.newPlot(                        "4ef98c22-9106-4bd6-a377-55f2e87c0aa3",                        [{"alignmentgroup":"True","hovertemplate":"Cluster=%{x}\u003cbr\u003eFrequency=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[559.0,12.0,6.0,5.0,3.0,3.0,2.0,2.0],"textposition":"outside","x":[0,7,6,1,2,5,4,3],"xaxis":"x","y":[559,12,6,5,3,3,2,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"typ ...
