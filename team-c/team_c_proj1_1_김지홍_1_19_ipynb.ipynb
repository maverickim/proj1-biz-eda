# %%
import pandas as pd
import google.generativeai as genai
import os
from time import sleep

# %%
import requests
from bs4 import BeautifulSoup

# URL 설정
url = "https://you.ctrip.com/sight/jeju1446512/134029217.html"

# HTTP 요청 헤더 설정 (필요 시)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# HTML 페이지 가져오기
response = requests.get(url, headers=headers)
response.encoding = 'utf-8'  # 인코딩 설정
html_content = response.text

# BeautifulSoup으로 HTML 파싱
soup = BeautifulSoup(html_content, "html.parser")

# 코멘트 모듈 선택
div_comment_module = soup.find("div", id="commentModule")

# 사용자 코멘트 데이터 추출
comments = []
if div_comment_module:
    comment_items = div_comment_module.find_all("div", class_="commentItem")
    for item in comment_items:
        user_name = item.find("div", class_="userName")
        score_info = item.find("span", class_="averageScore")
        comment_detail = item.find("div", class_="commentDetail")
        comment_time = item.find("div", class_="commentTime")

        user_name = user_name.get_text(strip=True) if user_name else "익명"
        score = score_info.get_text(strip=True) if score_info else "N/A"
        detail = comment_detail.get_text(strip=True) if comment_detail else ""
        time = comment_time.get_text(strip=True) if comment_time else ""

        comments.append({
            "user_name": user_name,
            "score": score,
            "detail": detail,
            "time": time
        })

# 결과 출력
for comment in comments:
    print(f"User: {comment['user_name']}")
    print(f"Score: {comment['score']}")
    print(f"Comment: {comment['detail']}")
    print(f"Time: {comment['time']}")
    print("-" * 50)

# 필요에 따라 CSV로 저장
import csv
with open("comments.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["user_name", "score", "detail", "time"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for comment in comments:
        writer.writerow(comment)
# Out:
# User: 香瓜子妈妈
# Score: 5分超棒
# Comment: 有孩子的一定要去，我觉得孩子们会喜欢的地方哦，特别是二楼的简餐厅，有一些简单的食物和蛋糕咖啡漂亮饮料等，价格也很合理！孩子们很喜欢 彩虹蛋糕才7500一块约rmb43，还有摆盘和一粒新鲜的车厘子！哈哈。拿铁冰咖啡6500约人民币37，也是有造型的。很值得。
# 户外有传说中的智秀同款打卡拍摄点，背影河边史努比哦。
# Time: 2023-09-19IP属地：上海
# --------------------------------------------------
# User: Snowsnowflake
# Score: 4分满意
# Comment: 很有趣,主题公园很大,公园内有很多可以体验的,可以制作明信片,在那里拍很多美照,有不同的场景和好玩的地方供游客拍照,值得一去。
# Time: 2025-01-02IP属地：未知
# --------------------------------------------------
# User: S.L仪
# Score: 5分超棒
# Comment: 十分方便，我们从日出嶂打车过去，费用大概60块，去到扫二维码换票，有室内和室外的游园区，各种场景，在里能玩上两三个小时。
# Time: 2024-09-01IP属地：广东
# --------------------------------------------------
# User: 嘻嘻你的大象腿
# Score: 5分超棒
# Comment: 我的快乐星球！去了以后爱上史努比，在这里买了好几样周边带回家。今年去日本看到有史努比门店也进去买了小玩偶，太可爱了！谁不爱史努比呢？
# 里面还有盖章活动，集齐印章可以兑换胸针。公园里有时段会有互动游戏，我们去的时间太尴尬了，工作人员全去吃饭午休，错过。
# 就是这里交通不太方便，早上出发一定要去汽车站门口坐去这里的公交，班次看小*书攻略。回程如果遇不到公交就用地图导航附近公交站坐车回城区。打车很贵，我们出发错过了公交，打车花了200多rmb。公交只需要十几块吧好像…
# Time: 2024-07-28IP属地：浙江
# ...

# %%
# prompt: 위 내용을 데이터 프레임 형태로 저장하는 코드를 작성

import pandas as pd
import google.generativeai as genai
import os
from time import sleep
import requests
from bs4 import BeautifulSoup
import csv

# URL 설정
url = "https://you.ctrip.com/sight/jeju1446512/134029217.html"

# HTTP 요청 헤더 설정 (필요 시)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# HTML 페이지 가져오기
response = requests.get(url, headers=headers)
response.encoding = 'utf-8'  # 인코딩 설정
html_content = response.text

# BeautifulSoup으로 HTML 파싱
soup = BeautifulSoup(html_content, "html.parser")

# 코멘트 모듈 선택
div_comment_module = soup.find("div", id="commentModule")

# 사용자 코멘트 데이터 추출
comments = []
if div_comment_module:
    comment_items = div_comment_module.find_all("div", class_="commentItem")
    for item in comment_items:
        user_name = item.find("div", class_="userName")
        score_info = item.find("span", class_="averageScore")
        comment_detail = item.find("div", class_="commentDetail")
        comment_time = item.find("div", class_="commentTime")

        user_name = user_name.get_text(strip=True) if user_name else "익명"
        score = score_info.get_text(strip=True) if score_info else "N/A"
        detail = comment_detail.get_text(strip=True) if comment_detail else ""
        time = comment_time.get_text(strip=True) if comment_time else ""

        comments.append({
            "user_name": user_name,
            "score": score,
            "detail": detail,
            "time": time
        })

# 데이터프레임 생성
df = pd.DataFrame(comments)

# 결과 출력 (선택 사항)
print(df)

# CSV 파일로 저장 (선택 사항)
df.to_csv("comments.csv", index=False, encoding="utf-8")
# Out:
#        user_name score                                             detail  \
# 0          香瓜子妈妈  5分超棒  有孩子的一定要去，我觉得孩子们会喜欢的地方哦，特别是二楼的简餐厅，有一些简单的食物和蛋糕咖啡...
# 1  Snowsnowflake  4分满意  很有趣,主题公园很大,公园内有很多可以体验的,可以制作明信片,在那里拍很多美照,有不同的场景...
# 2           S.L仪  5分超棒  十分方便，我们从日出嶂打车过去，费用大概60块，去到扫二维码换票，有室内和室外的游园区，各种...
# 3        嘻嘻你的大象腿  5分超棒  我的快乐星球！去了以后爱上史努比，在这里买了好几样周边带回家。今年去日本看到有史努比门店也进...
# 4            布鲁曼  5分超棒  景点排名第一是有道理的，整个园区挺大的，很好逛，也非常适合拍照！第一块区域是室内场馆，介绍了...
# 5    M48****6689  5分超棒  离市区稍远，打车公交也远远，推荐snoopy爱好者来玩！🐶室内展区有很多snoopy动画里的...
# 6          一朵飞莲呐  5分超棒  环境很好。可玩性很高。可以盖章换胸针。\n但是说到服务。可以说是无服务可言。买东西结账的时候...
# 7      Shanliang  5分超棒  本来没有对这里有期待 来玩了之后发现太精彩了 ！！装置和雕塑维护得很好 每一处都很精致 里面...
# 8        Agnes_z  5分超棒  看到史努比就不能错过！室内展区基本是人物关系和一些漫画经典场景重现。室外展区很大，有很多树木...
# 9           板栗宝子  5分超棒  说是需要预约\n实际买好，到柜台扫描二维码\n马上就能进去\n用二维码扫描闸机就能进去\n进...
#
#                   time
# 0    2023-09-19IP属地：上海
# 1    2025-01-02IP属地：未知
# 2    2024-09-01IP属地：广东
# 3    2024-07-28IP属地：浙江
# 4  2024-07-09IP属地：中国香港
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import csv
from time import sleep

# URL 설정 (페이지 번호 포함)
base_url = "https://you.ctrip.com/sight/jeju1446512/134029217.html"

# HTTP 요청 헤더 설정 (필요 시)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# 사용자 코멘트 데이터 추출 함수
def get_comments(page):
    url = f"{base_url}?page={page}"
    response = requests.get(url, headers=headers)
    response.encoding = 'utf-8'  # 인코딩 설정
    html_content = response.text

    # BeautifulSoup으로 HTML 파싱
    soup = BeautifulSoup(html_content, "html.parser")

    # 코멘트 모듈 선택
    div_comment_module = soup.find("div", id="commentModule")

    # 사용자 코멘트 데이터 추출
    comments = []
    if div_comment_module:
        comment_items = div_comment_module.find_all("div", class_="commentItem")
        for item in comment_items:
            user_name = item.find("div", class_="userName")
            score_info = item.find("span", class_="averageScore")
            comment_detail = item.find("div", class_="commentDetail")
            comment_time = item.find("div", class_="commentTime")

            user_name = user_name.get_text(strip=True) if user_name else "익명"
            score = score_info.get_text(strip=True) if score_info else "N/A"
            detail = comment_detail.get_text(strip=True) if comment_detail else ""
            time = comment_time.get_text(strip=True) if comment_time else ""

            comments.append({
                "user_name": user_name,
                "score": score,
                "detail": detail,
                "time": time
            })
    return comments

# 전체 코멘트 수집
total_comments = []
for page in range(1, 11):  # 1~10페이지 크롤링
    print(f"크롤링 중: {page}페이지")
    total_comments.extend(get_comments(page))
    sleep(2)  # 요청 간 대기 (반복적인 요청으로 인한 차단 방지)

# 데이터프레임 생성
df = pd.DataFrame(total_comments)

# 결과 출력 (선택 사항)
print(df)

# CSV 파일로 저장
df.to_csv("comments.csv", index=False, encoding="utf-8")
# Out:
# 크롤링 중: 1페이지
# 크롤링 중: 2페이지
# 크롤링 중: 3페이지
# 크롤링 중: 4페이지
# 크롤링 중: 5페이지
# 크롤링 중: 6페이지
# 크롤링 중: 7페이지
# 크롤링 중: 8페이지
# 크롤링 중: 9페이지
# 크롤링 중: 10페이지
#         user_name score                                             detail  \
# 0           香瓜子妈妈  5分超棒  有孩子的一定要去，我觉得孩子们会喜欢的地方哦，特别是二楼的简餐厅，有一些简单的食物和蛋糕咖啡...
# 1   Snowsnowflake  4分满意  很有趣,主题公园很大,公园内有很多可以体验的,可以制作明信片,在那里拍很多美照,有不同的场景...
# 2            S.L仪  5分超棒  十分方便，我们从日出嶂打车过去，费用大概60块，去到扫二维码换票，有室内和室外的游园区，各种...
# 3         嘻嘻你的大象腿  5分超棒  我的快乐星球！去了以后爱上史努比，在这里买了好几样周边带回家。今年去日本看到有史努比门店也进...
# 4             布鲁曼  5分超棒  景点排名第一是有道理的，整个园区挺大的，很好逛，也非常适合拍照！第一块区域是室内场馆，介绍了...
# ..            ...   ...                                                ...
# 95    M48****6689  5分超棒  离市区稍远，打车公交也远远，推荐snoopy爱好者来玩！🐶室内展区有很多snoopy动画里的...
# 96          一朵飞莲呐  5分超棒  环境很好。可玩性很高。可以盖章换胸针。\n但是说到服务。可以说是无服务可言。买东西结账的时候...
# 97      Shanliang  5分超棒  本来没有对这里有期待 来玩了之后发现太精彩了 ！！装置和雕塑维护得很好 每一处都很精致 里面...
# 98        Agnes_z  5分超棒  看到史努比就不能错过！室内展区基本是人物关系和一些漫画经典场景重现。室外展区很大，有很多树木...
# ...

# %%
# prompt: df['datail'] 를 5개의 주제로 토픽모델링을 하고 각 토픽별 주요 키워드와 가중치 20개씩 추출

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# 토픽 모델링 (LDA)
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english') # Adjust parameters as needed
tfidf = vectorizer.fit_transform(df['detail'])

lda = LatentDirichletAllocation(n_components=5, random_state=42) # 5개의 토픽
lda.fit(tfidf)

# 각 토픽별 주요 키워드 추출
feature_names = vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda.components_):
    print(f"Topic {topic_idx + 1}:")
    top_keywords_idx = topic.argsort()[:-21:-1] # 상위 20개 키워드
    top_keywords = [feature_names[i] for i in top_keywords_idx]
    top_weights = [topic[i] for i in top_keywords_idx]

    for keyword, weight in zip(top_keywords, top_weights):
        print(f"  - {keyword}: {weight:.4f}")  # 가중치 소수점 4자리까지 표시
    print("-" * 20)
# Out:
# Topic 1:
#   - 来玩了之后发现太精彩了: 3.2151
#   - 每一处都很精致: 3.2151
#   - 本来没有对这里有期待: 3.2151
#   - 三小时左右可以逛好: 3.2151
#   - 里面有很多很细的小东西可以一直一直逛: 3.2151
#   - 户外的树木都修理的很好: 3.2151
#   - 很感动: 3.2151
#   - 到处都有snoopy和大自然融合在一起的场景: 3.2151
#   - 装置和雕塑维护得很好: 3.2151
#   - 室外馆100分钟: 3.2151
#   - 大概室内馆60分钟: 3.2151
#   - 有不同的场景和好玩的地方供游客拍照: 0.2000
#   - 很有趣: 0.2000
#   - 在那里拍很多美照: 0.2000
#   - 可以制作明信片: 0.2000
#   - 公园内有很多可以体验的: 0.2000
#   - 值得一去: 0.2000
#   - 主题公园很大: 0.2000
#   - 室内展区有很多snoopy动画里的片段: 0.2000
#   - 室外展区有很多散落在自然中的snoopy: 0.2000
# --------------------
# Topic 2:
#   - 各种场景: 3.9796
#   - 有室内和室外的游园区: 3.9796
#   - 在里能玩上两三个小时: 3.9796
#   - 我们从日出嶂打车过去: 3.9796
#   - 十分方便: 3.9796
#   - 去到扫二维码换票: 3.9796
#   - 费用大概60块: 3.9796
#   - 探险: 2.8726
#   - 小溪: 2.8726
#   - 第一块区域是室内场馆: 2.8726
#   - 很好逛: 2.8726
#   - 的小挑战: 2.8726
#   - 很不错: 2.8726
#   - 第二块区域为室外部分: 2.8726
#   - 还有小朋友: 2.8726
#   - 整个园区挺大的: 2.8726
#   - 瀑布等自然景观组成: 2.8726
#   - 介绍了史努比的一些基础知识: 2.8726
#   - 也非常适合拍照: 2.8726
#   - 景点排名第一是有道理的: 2.8726
# ...

# %%
# prompt: df['detail'] 를 TF-IDF로 5개의 주제로 토픽모델링을 하고 각 토픽별 주요 키워드와 가중치 20개씩 추출

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Assuming 'df' is already loaded with your data
# If not, load it first: df = pd.read_csv("comments.csv")

# 토픽 모델링 (LDA)
vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english') # Adjust parameters as needed
tfidf = vectorizer.fit_transform(df['detail'])

lda = LatentDirichletAllocation(n_components=5, random_state=42) # 5개의 토픽
lda.fit(tfidf)

# 각 토픽별 주요 키워드 추출
feature_names = vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda.components_):
    print(f"Topic {topic_idx + 1}:")
    top_keywords_idx = topic.argsort()[:-21:-1] # 상위 20개 키워드
    top_keywords = [feature_names[i] for i in top_keywords_idx]
    top_weights = [topic[i] for i in top_keywords_idx]

    for keyword, weight in zip(top_keywords, top_weights):
        print(f"  - {keyword}: {weight:.4f}")  # 가중치 소수점 4자리까지 표시
    print("-" * 20)
# Out:
# Topic 1:
#   - 来玩了之后发现太精彩了: 3.2151
#   - 每一处都很精致: 3.2151
#   - 本来没有对这里有期待: 3.2151
#   - 三小时左右可以逛好: 3.2151
#   - 里面有很多很细的小东西可以一直一直逛: 3.2151
#   - 户外的树木都修理的很好: 3.2151
#   - 很感动: 3.2151
#   - 到处都有snoopy和大自然融合在一起的场景: 3.2151
#   - 装置和雕塑维护得很好: 3.2151
#   - 室外馆100分钟: 3.2151
#   - 大概室内馆60分钟: 3.2151
#   - 有不同的场景和好玩的地方供游客拍照: 0.2000
#   - 很有趣: 0.2000
#   - 在那里拍很多美照: 0.2000
#   - 可以制作明信片: 0.2000
#   - 公园内有很多可以体验的: 0.2000
#   - 值得一去: 0.2000
#   - 主题公园很大: 0.2000
#   - 室内展区有很多snoopy动画里的片段: 0.2000
#   - 室外展区有很多散落在自然中的snoopy: 0.2000
# --------------------
# Topic 2:
#   - 各种场景: 3.9796
#   - 有室内和室外的游园区: 3.9796
#   - 在里能玩上两三个小时: 3.9796
#   - 我们从日出嶂打车过去: 3.9796
#   - 十分方便: 3.9796
#   - 去到扫二维码换票: 3.9796
#   - 费用大概60块: 3.9796
#   - 探险: 2.8726
#   - 小溪: 2.8726
#   - 第一块区域是室内场馆: 2.8726
#   - 很好逛: 2.8726
#   - 的小挑战: 2.8726
#   - 很不错: 2.8726
#   - 第二块区域为室外部分: 2.8726
#   - 还有小朋友: 2.8726
#   - 整个园区挺大的: 2.8726
#   - 瀑布等自然景观组成: 2.8726
#   - 介绍了史努比的一些基础知识: 2.8726
#   - 也非常适合拍照: 2.8726
#   - 景点排名第一是有道理的: 2.8726
# ...

# %%
pip install google-generativeai

# %%
import pandas as pd
import google.generativeai as genai
from time import sleep

# Gemini API 키 설정
genai.configure(api_key='AIzaSyAQpSWApfPs1NQdtq93DishjPmbkFYTM6w')

# Gemini 모델 설정
model = genai.GenerativeModel(model_name='gemini-pro')  # 모델 이름 수정

def translate_text(text):
    try:
        prompt = f"다음 텍스트를 한국어로 번역해주세요: {text}"
        response = model.generate_content(prompt)
        # 응답 구조에 맞게 수정
        return response['choices'][0]['text']
    except Exception as e:
        print(f"번역 중 오류 발생: {e}")
        return text

# CSV 파일 읽기
df = pd.read_csv('comments.csv')

# 번역할 열 지정
column_to_translate = 'review'  # 실제 열 이름으로 변경

# 번역 실행
df[f'{column_to_translate}_korean'] = df[column_to_translate].apply(translate_text)

# 결과 저장
df.to_excel('translated_reviews.xlsx', index=False, engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'review'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-94bc3cba6af3> in <cell line: 0>()
#      26
#      27 # 번역 실행
# ...

# %%
# prompt: ctrip_srp_30pages.csv 를 읽는 코드를 작성

import pandas as pd

df = pd.read_csv('ctrip_srp_30pages.csv')
df
# Out:
#                 Title                                          Image URL  \
# 0               史努比乐园  https://dimg04.c-ctrip.com/images/1lo0j12000fm...
# 1                  牛岛  https://dimg04.c-ctrip.com/images/100w1f000001...
# 2           乱打秀(济州剧场)  https://dimg04.c-ctrip.com/images/0101e12000as...
# 3    ARTE全沉浸式美术馆-韩国济州  https://dimg04.c-ctrip.com/images/0100612000f6...
# 4     济州Ecoland生态主题乐园  https://dimg04.c-ctrip.com/images/100f1f000001...
# ..                ...                                                ...
# 295        Jeojioreum  https://dimg04.c-ctrip.com/images/fd/tg/g1/M06...
# 296        KBS 제주방송총국  https://dimg04.c-ctrip.com/images/fd/tg/g1/M06...
# 297    Wolryeong Port  https://dimg04.c-ctrip.com/images/fd/tg/g1/M06...
# 298     Art Space IAa  https://dimg04.c-ctrip.com/images/0102u1200086...
# 299          信不信由你博物馆  https://dimg04.c-ctrip.com/images/100t18000001...
#
#                                            Detail Link  Score  Review Count  \
# ...

# %%
column_to_translate = 'review_ko'  # 실제 번역하고 싶은 열 이름으로 변경하세요

# %%
df[f'{column_to_translate}_korean'] = df[column_to_translate].apply(translate_text)

결과를 새로운 Excel 파일로 저장
df.to_excel('translated_reviews.xlsx', index=False)
# Out:
#   File "<ipython-input-24-7c04e51ca599>", line 3
#     결과를 새로운 Excel 파일로 저장
#         ^
# SyntaxError: invalid syntax
