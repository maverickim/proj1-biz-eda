# %%
# CP949 encoding의 csv 파일 불러오기
import pandas as pd

df = pd.read_csv('df_flattened_final.csv', encoding='CP949')
print(df.head())
# Out:
#    event_date                   event_timestamp   event_name  \
# 0    20241113  2024-11-13 00:06:00.541000+09:00  screen_view
# 1    20241113  2024-11-13 00:06:03.707001+09:00       scroll
# 2    20241113  2024-11-13 00:06:03.707002+09:00       scroll
# 3    20241113  2024-11-13 00:06:03.707003+09:00       scroll
# 4    20241113  2024-11-13 00:06:04.025004+09:00       scroll
#
#            event_previous_timestamp  event_value_in_usd  \
# 0  2024-11-12 23:58:23.577000+09:00                 NaN
# 1  2024-11-12 23:58:26.667001+09:00                 NaN
# 2  2024-11-13 00:06:03.707002+09:00                 NaN
# 3  2024-11-13 00:06:03.707003+09:00                 NaN
# 4  2024-11-13 00:06:03.707004+09:00                 NaN
#
#    event_bundle_sequence_id  event_server_timestamp_offset  user_id  \
# 0                       468                        1115394  39827.0
# 1                       468                        1115394  39827.0
# 2                       468                        1115394  39827.0
# 3                       468                        1115394  39827.0
# 4                       468                        1115394  39827.0
#
#                      user_pseudo_id        user_first_touch_timestamp  ...  \
# 0  154e3be9cecd0af9307e920fcc4f9476  2024-05-30 20:28:33.956000+09:00  ...
# 1  154e3be9cecd0af9307e920fcc4f9476  2024-05-30 20:28:33.956000+09:00  ...
# 2  154e3be9cecd0af9307e920fcc4f9476  2024-05-30 20:28:33.956000+09:00  ...
# 3  154e3be9cecd0af9307e920fcc4f9476  2024-05-30 20:28:33.956000+09:00  ...
# 4  154e3be9cecd0af9307e920fcc4f9476  2024-05-30 20:28:33.956000+09:00  ...
#
#    session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.creative_version  \
# 0                                                                                            (not set)
# 1                                                                                            (not set)
# 2                                                                                            (not set)
# 3                                                                                            (not set)
# 4                                                                                            (not set)
#
#   session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.placement_id  \
# 0                                                                                       (not set)
# 1                                                                                       (not set)
# 2                                                                                       (not set)
# 3                                                                                       (not set)
# 4                                                                                       (not set)
#
#    session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.placement_cost_structure  \
# 0                                                                                                    (not set)
# 1                                                                                                    (not set)
# 2                                                                                                    (not set)
# 3                                                                                                    (not set)
# 4                                                                                                    (not set)
#
#    session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.placement_name  \
# 0                                                                                          (not set)
# 1                                                                                          (not set)
# 2                                                                                          (not set)
# 3                                                                                          (not set)
# 4                                                                                          (not set)
#
#    session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.rendering_id  \
# 0                                                                                        (not set)
# 1                                                                                        (not set)
# 2                                                                                        (not set)
# 3                                                                                        (not set)
# 4                                                                                        (not set)
#
#    session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.site_id  \
# 0                                                                                   (not set)
# 1                                                                                   (not set)
# 2                                                                                   (not set)
# 3                                                                                   (not set)
# 4                                                                                   (not set)
#
#    session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.site_name  \
# 0                                                                                     (not set)
# 1                                                                                     (not set)
# 2                                                                                     (not set)
# 3                                                                                     (not set)
# 4                                                                                     (not set)
#
#   session_traffic_source_last_click.session_traffic_source_last_click.dv360_campaign  \
# 0                                                                                NaN
# 1                                                                                NaN
# 2                                                                                NaN
# 3                                                                                NaN
# 4                                                                                NaN
#
#   publisher.publisher               time_diff
# 0                 NaN  0 days 00:07:36.964000
# 1                 NaN  0 days 00:07:37.040000
# 2                 NaN         0 days 00:00:00
# 3                 NaN         0 days 00:00:00
# 4                 NaN  0 days 00:00:00.318000
#
# [5 rows x 212 columns]

# %%
# prompt: df.head(1) 을 transpose해서 모든 column이 다 보이는 조건 코드

import pandas as pd

# CP949 encoding의 csv 파일 불러오기
df = pd.read_csv('df_flattened_final.csv', encoding='CP949')

# head(1)을 transpose하고 모든 column이 보이도록 설정
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
  print(df.head(1).T)
# Out:
#                                                                                                                                                                0
# event_date                                                                                                                                              20241113
# event_timestamp                                                                                                                 2024-11-13 00:06:00.541000+09:00
# event_name                                                                                                                                           screen_view
# event_previous_timestamp                                                                                                        2024-11-12 23:58:23.577000+09:00
# event_value_in_usd                                                                                                                                           NaN
# event_bundle_sequence_id                                                                                                                                     468
# event_server_timestamp_offset                                                                                                                            1115394
# user_id                                                                                                                                                  39827.0
# user_pseudo_id                                                                                                                  154e3be9cecd0af9307e920fcc4f9476
# user_first_touch_timestamp                                                                                                      2024-05-30 20:28:33.956000+09:00
# stream_id                                                                                                                                             2330052538
# platform                                                                                                                                                 ANDROID
# is_active_user                                                                                                                                              True
# batch_event_index                                                                                                                                              1
# batch_page_id                                                                                                                                                NaN
# batch_ordering_id                                                                                                                                            NaN
# items.item_id                                                                                                                                                NaN
# items.item_name                                                                                                                                              NaN
# items.item_brand                                                                                                                                             NaN
# items.item_variant                                                                                                                                           NaN
# items.item_category                                                                                                                                          NaN
# items.item_category2                                                                                                                                         NaN
# items.item_category3                                                                                                                                         NaN
# items.item_category4                                                                                                                                         NaN
# items.item_category5                                                                                                                                         NaN
# items.price_in_usd                                                                                                                                           NaN
# items.price                                                                                                                                                  NaN
# items.quantity                                                                                                                                               NaN
# items.item_revenue_in_usd                                                                                                                                    NaN
# items.item_revenue                                                                                                                                           NaN
# items.item_refund_in_usd                                                                                                                                     NaN
# items.item_refund                                                                                                                                            NaN
# items.coupon                                                                                                                                                 NaN
# items.affiliation                                                                                                                                            NaN
# items.location_id                                                                                                                                            NaN
# items.item_list_id                                                                                                                                           NaN
# items.item_list_name                                                                                                                                         NaN
# items.item_list_index                                                                                                                                        NaN
# items.promotion_id                                                                                                                                           NaN
# items.promotion_name                                                                                                                                         NaN
# items.creative_name                                                                                                                                          NaN
# items.creative_slot                                                                                                                                          NaN
# items.item_params                                                                                                                                            NaN
# event_params.ga_session_number                                                                                                                               171
# event_params.ga_session_id                                                                                                                            1731423503
# event_params.firebase_screen_class                                                                                                                  MainActivity
# event_params.firebase_event_origin                                                                                                                          auto
# event_params.firebase_screen_id                                                                                                           -7731334501732282368.0
# event_params.percent_scrolled                                                                                                                                NaN
# event_params.engagement_time_msec                                                                                                                            NaN
# event_params.entrances                                                                                                                                       NaN
# event_params.firebase_conversion                                                                                                                             NaN
# event_params.channel                                                                                                                                         NaN
# event_params.engaged_session_event                                                                                                                           NaN
# event_params.message_type                                                                                                                                    NaN
# event_params.firebase_previous_class                                                                                                                         NaN
# event_params.firebase_screen                                                                                                                                 NaN
# event_params.firebase_previous_id                                                                                                                            NaN
# event_params.session_engaged                                                                                                                                 NaN
# event_params.tab_name                                                                                                                                        NaN
# event_params.firebase_previous_screen                                                                                                                        NaN
# event_params.style_name                                                                                                                                      NaN
# event_params.click_section                                                                                                                                   NaN
# event_params.click_text                                                                                                                                      NaN
# event_params.search_term                                                                                                                                     NaN
# event_params.currency                                                                                                                                        NaN
# event_params.platform                                                                                                                                        NaN
# event_params.product_name                                                                                                                                    NaN
# event_params.button_type                                                                                                                                     NaN
# event_params.item_list_name                                                                                                                                  NaN
# event_params.step                                                                                                                                            NaN
# event_params.brand_name                                                                                                                                      NaN
# event_params.withdrawal_reason                                                                                                                               NaN
# event_params.previous_app_version                                                                                                                            NaN
# event_params.previous_os_version                                                                                                                             NaN
# event_params.debug_event                                                                                                                                     NaN
# event_params.campaign                                                                                                                                        NaN
# event_params.source                                                                                                                                          NaN
# event_params.campaign_info_source                                                                                                                            NaN
# event_params.error_value                                                                                                                                     NaN
# event_params.firebase_error                                                                                                                                  NaN
# event_params.dynamic_link_accept_time                                                                                                                        NaN
# event_params.dynamic_link_link_name                                                                                                                          NaN
# event_params.content_title                                                                                                                                   NaN
# event_params.category                                                                                                                                        NaN
# privacy_info.privacy_info.analytics_storage                                                                                                                  Yes
# privacy_info.privacy_info.ads_storage                                                                                                                        Yes
# privacy_info.privacy_info.uses_transient_token                                                                                                                No
# user_properties.na_face_type                                                                                                                                 사각형
# user_properties.na_gender                                                                                                                                     여자
# user_properties.na_body_type                                                                                                                               모래시계형
# user_properties.ga_session_id                                                                                                                         1731423503
# user_properties.na_age                                                                                                                                      21.0
# user_properties.na_shoulder                                                                                                                                   크다
# user_properties.ga_session_number                                                                                                                            171
# user_properties.na_bottom                                                                                                                                    미설정
# user_properties.na_thigh                                                                                                                                      크다
# user_properties.na_middle                                                                                                                                     크다
# user_properties.na_job                                                                                                                                        학생
# user_properties.na_skin_type                                                                                                                                  가을
# user_properties.na_waist                                                                                                                                      크다
# user_properties.first_open_time                                                                                                 1970-01-21 05:57:50.400000+09:00
# user_properties.na_top                                                                                                                                       미설정
# user_properties.na_height                                                                                                                                  160.0
# user_properties.na_weight                                                                                                                                    NaN
# user_properties.color1_with_priority                                                                                                                         NaN
# user_properties.color2_with_priority                                                                                                                         NaN
# user_properties.eot_height                                                                                                                                   NaN
# user_properties.color3_with_priority                                                                                                                         NaN
# user_properties._ltv_KRW                                                                                                                                     NaN
# user_properties.height                                                                                                                                       NaN
# user_properties.na_job_extra                                                                                                                                 NaN
# user_ltv.user_ltv                                                                                                                                            NaN
# user_ltv.user_ltv.revenue                                                                                                                                    NaN
# user_ltv.user_ltv.currency                                                                                                                                   NaN
# device.device.category                                                                                                                                    mobile
# device.device.mobile_brand_name                                                                                                                          Samsung
# device.device.mobile_model_name                                                                                                                         SM-A528B
# device.device.mobile_marketing_name                                                                                                               Galaxy A52s 5G
# device.device.mobile_os_hardware_model                                                                                                                  SM-A528B
# device.device.operating_system                                                                                                                           Android
# device.device.operating_system_version                                                                                                                Android 14
# device.device.vendor_id                                                                                                                                      NaN
# device.device.advertising_id                                                                                                                                 NaN
# device.device.language                                                                                                                                     ko-kr
# device.device.is_limited_ad_tracking                                                                                                                          No
# device.device.time_zone_offset_seconds                                                                                                                     32400
# device.device.browser                                                                                                                                        NaN
# device.device.browser_version                                                                                                                                NaN
# device.device.web_info                                                                                                                                       NaN
# geo.geo.city                                                                                                                                               Seoul
# geo.geo.country                                                                                                                                      South Korea
# geo.geo.continent                                                                                                                                           Asia
# geo.geo.region                                                                                                                                             Seoul
# geo.geo.sub_continent                                                                                                                               Eastern Asia
# geo.geo.metro                                                                                                                                          (not set)
# app_info.app_info.id                                                                                                           com.fastcampus.innercircle.bizeda
# app_info.app_info.version                                                                                                                                  3.1.7
# app_info.app_info.install_store                                                                                                                              NaN
# app_info.app_info.firebase_app_id                                                                                 1:1038028525994:android:8f9fffd18a1189e4afdbd3
# app_info.app_info.install_source                                                                                                             com.android.vending
# traffic_source.traffic_source.name                                                                                                                           NaN
# traffic_source.traffic_source.medium                                                                                                                     organic
# traffic_source.traffic_source.source                                                                                                                 google-play
# traffic_source.traffic_source                                                                                                                                NaN
# event_dimensions.event_dimensions                                                                                                                            NaN
# ecommerce.ecommerce                                                                                                                                          NaN
# ecommerce.ecommerce.total_item_quantity                                                                                                                      NaN
# ecommerce.ecommerce.purchase_revenue_in_usd                                                                                                                  NaN
# ecommerce.ecommerce.purchase_revenue                                                                                                                         NaN
# ecommerce.ecommerce.refund_value_in_usd                                                                                                                      NaN
# ecommerce.ecommerce.refund_value                                                                                                                             NaN
# ecommerce.ecommerce.shipping_value_in_usd                                                                                                                    NaN
# ecommerce.ecommerce.shipping_value                                                                                                                           NaN
# ecommerce.ecommerce.tax_value_in_usd                                                                                                                         NaN
# ecommerce.ecommerce.tax_value                                                                                                                                NaN
# ecommerce.ecommerce.unique_items                                                                                                                             NaN
# ecommerce.ecommerce.transaction_id                                                                                                                           NaN
# collected_traffic_source.collected_traffic_source                                                                                                            NaN
# collected_traffic_source.collected_traffic_source.manual_campaign_id                                                                                         NaN
# collected_traffic_source.collected_traffic_source.manual_campaign_name                                                                                       NaN
# collected_traffic_source.collected_traffic_source.manual_source                                                                                              NaN
# collected_traffic_source.collected_traffic_source.manual_medium                                                                                              NaN
# collected_traffic_source.collected_traffic_source.manual_term                                                                                                NaN
# collected_traffic_source.collected_traffic_source.manual_content                                                                                             NaN
# collected_traffic_source.collected_traffic_source.manual_source_platform                                                                                     NaN
# collected_traffic_source.collected_traffic_source.manual_creative_format                                                                                     NaN
# collected_traffic_source.collected_traffic_source.manual_marketing_tactic                                                                                    NaN
# collected_traffic_source.collected_traffic_source.gclid                                                                                                      NaN
# collected_traffic_source.collected_traffic_source.dclid                                                                                                      NaN
# collected_traffic_source.collected_traffic_source.srsltid                                                                                                    NaN
# session_traffic_source_last_click.session_traffic_source_last_click.manual_campaign.campaign_id                                                        (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.manual_campaign.campaign_name                                                      (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.manual_campaign.source                                                             (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.manual_campaign.medium                                                             (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.manual_campaign.term                                                               (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.manual_campaign.content                                                            (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.manual_campaign.source_platform                                                    (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.manual_campaign.creative_format                                                    (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.manual_campaign.marketing_tactic                                                   (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.google_ads_campaign                                                                      NaN
# session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.campaign_id                                                       NaN
# session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.campaign_name                                                (direct)
# session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.source                                                       (direct)
# session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.medium                                                         (none)
# session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.source_platform                                                Manual
# session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.default_channel_group                                          Direct
# session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.primary_channel_group                                          Direct
# session_traffic_source_last_click.session_traffic_source_last_click.sa360_campaign                                                                           NaN
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.campaign_id                                                         (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.campaign_name                                                       (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.source                                                              (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.medium                                                              (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.account_id                                                          (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.account_name                                                        (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.advertiser_id                                                       (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.advertiser_name                                                     (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.creative_id                                                         (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.creative_format                                                     (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.creative_name                                                       (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.creative_type                                                       (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.creative_type_id                                                    (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.creative_version                                                    (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.placement_id                                                        (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.placement_cost_structure                                            (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.placement_name                                                      (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.rendering_id                                                        (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.site_id                                                             (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.site_name                                                           (not set)
# session_traffic_source_last_click.session_traffic_source_last_click.dv360_campaign                                                                           NaN
# publisher.publisher                                                                                                                                          NaN
# time_diff                                                                                                                                 0 days 00:07:36.964000

# %% [markdown]
# ### **GA4 데이터 컬럼 설명 **
#
# ---
#
# ### **1. 이벤트 관련 데이터**
# - `event_date`: 이벤트 발생 날짜 (YYYYMMDD)
# - `event_timestamp`: 이벤트 발생 시간 (Unix Timestamp)
# - `event_name`: 이벤트 유형 (`screen_view`, `scroll` 등)
# - `event_previous_timestamp`: 이전 이벤트 발생 시간
# - `event_value_in_usd`: 이벤트로 인한 수익 (USD 기준)
# - `event_bundle_sequence_id`: 동일 번들 내 이벤트 순서
# - `event_server_timestamp_offset`: 서버 시간 보정값
# - `time_diff` : 이벤트 발생시간 - 이전 이벤트 발생시간
#
# ---
#
# ### **2. 사용자 관련 데이터**
# - `user_id`: 로그인한 사용자 ID
# - `user_pseudo_id`: 익명 사용자 ID
# - `user_first_touch_timestamp`: 사용자의 첫 방문 시점
# - `is_active_user`: 현재 세션이 활성 상태인지 여부
# - `batch_event_index`: 배치 처리된 이벤트의 인덱스
# - `batch_page_id`: 배치 처리된 페이지 ID
# - `batch_ordering_id`: 배치 처리된 주문 ID
#
# ---
#
# ### **3. 아이템(상품) 관련 데이터**
# - `items.item_id`: 상품 ID
# - `items.item_name`: 상품 이름
# - `items.item_brand`: 상품 브랜드
# - `items.item_variant`: 상품 모델 또는 변형 정보
# - `items.item_category`: 상품 카테고리
# - `items.item_category2`: 추가 상품 카테고리
# - `items.item_category3`: 추가 상품 카테고리
# - `items.item_category4`: 추가 상품 카테고리
# - `items.item_category5`: 추가 상품 카테고리
# - `items.price_in_usd`: 상품 가격 (USD)
# - `items.price`: 상품 가격 (로컬 화폐 기준)
# - `items.quantity`: 상품 구매 수량
# - `items.item_revenue_in_usd`: 상품 매출 (USD)
# - `items.item_revenue`: 상품 매출 (로컬 화폐 기준)
# - `items.item_refund_in_usd`: 상품 환불 금액 (USD)
# - `items.item_refund`: 상품 환불 금액 (로컬 화폐 기준)
# - `items.coupon`: 사용된 쿠폰 코드
# - `items.affiliation`: 제휴 정보
# - `items.location_id`: 상품 위치 ID
# - `items.item_list_id`: 상품 목록 ID
# - `items.item_list_name`: 상품 목록 이름
# - `items.item_list_index`: 상품 목록 내 인덱스
# - `items.promotion_id`: 프로모션 ID
# - `items.promotion_name`: 프로모션 이름
# - `items.creative_name`: 광고 크리에이티브 이름
# - `items.creative_slot`: 광고 크리에이티브 슬롯
# - `items.item_params`: 상품 관련 추가 파라미터
#
# ---
#
# ### **4. 이벤트 파라미터 데이터**
# - `event_params.ga_session_number`: 세션 횟수
# - `event_params.ga_session_id`: 세션 ID
# - `event_params.firebase_screen_class`: Firebase 화면 클래스
# - `event_params.firebase_event_origin`: Firebase 이벤트 출처
# - `event_params.firebase_screen_id`: Firebase 화면 ID
# - `event_params.percent_scrolled`: 사용자가 스크롤한 비율 (%)
# - `event_params.engagement_time_msec`: 참여 시간 (밀리초)
# - `event_params.entrances`: 첫 방문 여부
# - `event_params.firebase_conversion`: Firebase 전환 이벤트 여부
# - `event_params.channel`: 트래픽 채널
# - `event_params.engaged_session_event`: 참여 세션 여부
# - `event_params.message_type`: 메시지 유형
# - `event_params.firebase_previous_class`: 이전 Firebase 화면 클래스
# - `event_params.firebase_screen`: Firebase 현재 화면
# - `event_params.firebase_previous_id`: 이전 Firebase 화면 ID
# - `event_params.session_engaged`: 세션 참여 여부
# - `event_params.tab_name`: 선택한 탭 이름
# - `event_params.firebase_previous_screen`: 이전 Firebase 화면 이름
# - `event_params.style_name`: 스타일 이름
# - `event_params.click_section`: 클릭한 영역
# - `event_params.click_text`: 클릭한 텍스트
# - `event_params.search_term`: 검색어
# - `event_params.currency`: 화폐 단위
# - `event_params.platform`: 플랫폼 정보
# - `event_params.product_name`: 제품 이름
# - `event_params.button_type`: 클릭한 버튼 유형
# - `event_params.item_list_name`: 클릭한 상품 목록 이름
# - `event_params.step`: 특정 이벤트 단계 정보
# - `event_params.brand_name`: 브랜드 이름
# - `event_params.withdrawal_reason`: 사용자의 이탈 이유
# - `event_params.previous_app_version`: 이전 앱 버전
# - `event_params.previous_os_version`: 이전 OS 버전
# - `event_params.debug_event`: 디버그 이벤트 여부
# - `event_params.campaign`: 캠페인 이름
# - `event_params.source`: 유입 경로
# - `event_params.campaign_info_source`: 캠페인 정보 출처
# - `event_params.error_value`: 오류 값
# - `event_params.firebase_error`: Firebase 오류 코드
# - `event_params.dynamic_link_accept_time`: 동적 링크 수락 시간
# - `event_params.dynamic_link_link_name`: 동적 링크 이름
# - `event_params.content_title`: 콘텐츠 제목
# - `event_params.category`: 콘텐츠 카테고리
#
# ---
#
# ### **5. 개인정보 및 광고 설정**
# - `privacy_info.privacy_info.analytics_storage`: 분석 데이터 저장 허용 여부
# - `privacy_info.privacy_info.ads_storage`: 광고 데이터 저장 허용 여부
# - `privacy_info.privacy_info.uses_transient_token`: 임시 토큰 사용 여부
#
# ---
#
# ### **6. 사용자 속성 데이터**
# - `user_properties.na_face_type`: 사용자 얼굴형
# - `user_properties.na_gender`: 사용자 성별
# - `user_properties.na_body_type`: 사용자 체형
# - `user_properties.na_age`: 사용자 나이
# - `user_properties.na_shoulder`: 어깨 크기
# - `user_properties.na_bottom`: 하의 사이즈
# - `user_properties.na_thigh`: 허벅지 크기
# - `user_properties.na_middle`: 허리 크기
# - `user_properties.na_job`: 사용자 직업
# - `user_properties.na_skin_type`: 피부 타입
# - `user_properties.na_waist`: 허리 둘레
# - `user_properties.na_height`: 키
# - `user_properties.na_weight`: 몸무게
# - `user_properties.color1_with_priority`: 선호 색상 1
# - `user_properties.color2_with_priority`: 선호 색상 2
# - `user_properties.color3_with_priority`: 선호 색상 3
# - `user_properties.eot_height`: 키 범주
# - `user_properties._ltv_KRW`: 사용자의 Lifetime Value (KRW 기준)
#
# ---
#
# ### **7. 디바이스 정보**
# - `device.device.category`: 디바이스 유형 (mobile, desktop)
# - `device.device.mobile_brand_name`: 모바일 브랜드
# - `device.device.mobile_model_name`: 모바일 모델
# - `device.device.operating_system`: 운영체제
# - `device.device.operating_system_version`: OS 버전
# - `device.device.vendor_id`: 디바이스 벤더 ID
# - `device.device.advertising_id`: 광고 ID
# - `device.device.language`: 사용자 언어
# - `device.device.time_zone_offset_seconds`: 시간대 오프셋
#
# ---
#
# ### **8. 위치 정보**
# - `geo.geo.city`: 도시
# - `geo.geo.country`: 국가
# - `geo.geo.region`: 지역
# - `geo.geo.continent`: 대륙
# - `geo.geo.sub_continent`: 소대륙
#
# ---
#
# ### **9. 앱 정보**
# - `app_info.app_info.id`: 앱 패키지 ID
# - `app_info.app_info.version`: 앱 버전
# - `app_info.app_info.install_source`: 설치 경로
#
# ---
#
# ### **10. 퍼블리셔 정보**
# - `publisher.publisher`: 퍼블리셔 정보

# %% [markdown]
# 먼저, `df_flattened_final.csv` 파일을 확인하여 데이터의 구조와 내용을 분석한 후, 비즈니스 분석 관점에서 어떤 인사이트를 도출할 수 있을지 가이드를 제공할게. 파일을 로드하고 데이터의 주요 특성을 살펴볼게.
#
# ### **데이터 개요 및 분석 가이드라인**
#
# #### **1. 데이터 구조 및 특성**
# - **총 1440개의 행, 212개의 컬럼**
# - **컬럼 타입**
#   - `float64 (63개)`, `int64 (10개)`, `object (138개)`, `bool (1개)`
# - **주요 컬럼**
#   - **시간 관련 데이터**: `event_date`, `event_timestamp`, `event_previous_timestamp`, `user_first_touch_timestamp`
#   - **이벤트 관련 데이터**: `event_name`, `event_value_in_usd`, `event_bundle_sequence_id`
#   - **유저 관련 데이터**: `user_id`, `user_pseudo_id`
#   - **세션 관련 데이터**: `session_traffic_source_last_click`, `publisher`, `time_diff`
#
# ---
#
# ### **2. 비즈니스 분석 방향**
# 이 데이터는 **사용자 행동 분석(User Behavior Analytics)** 및 **마케팅 효과 분석**을 수행하는 데 적합해 보임. 이를 기반으로 다음과 같은 분석을 수행할 수 있음.
#
# #### **① 사용자 행동 분석**
# > **목표:** 사용자의 웹사이트 및 앱 내 활동 패턴을 파악하고, 핵심 사용자 흐름(Funnel)을 분석.
#
# - **방문 패턴 분석**
#   - `event_name`을 기반으로 사용자의 행동(스크롤, 페이지뷰, 클릭 등)이 어떤 패턴을 가지는지 분석.
#   - 특정 이벤트(예: `conversion` 또는 `purchase`)를 중심으로 이전 행동 흐름을 추적.
#
# - **세션 분석**
#   - `time_diff`를 활용하여 평균 세션 길이 측정.
#   - `user_id`를 기준으로 세션당 이벤트 개수 및 평균 체류 시간 분석.
#   - `user_first_touch_timestamp`을 이용해 신규/재방문 사용자 비율 비교.
#
# - **코호트 분석 (Cohort Analysis)**
#   - `user_first_touch_timestamp`을 기준으로 가입 시점을 정리하여, 특정 기간 동안의 유지율 분석.
#
# #### **② 마케팅 효과 분석**
# > **목표:** 유입 경로별 전환율(Conversion Rate) 및 광고 효과 분석.
#
# - **유입 채널 분석**
#   - `session_traffic_source_last_click` 데이터를 활용하여 주요 유입 경로(Organic, Paid, Referral 등) 분석.
#   - 유입 경로별 전환율을 계산하여 가장 효과적인 채널 파악.
#
# - **광고 캠페인 성과 분석**
#   - `cm360_campaign.*` 관련 데이터를 활용하여 각 광고 캠페인의 성과 측정.
#   - `placement_id` 및 `placement_name`을 활용해 광고 소재별 성과 비교.
#
# - **구매 이벤트 분석 (Conversion Analysis)**
#   - `event_value_in_usd`를 활용해 이벤트별 매출 기여도 분석.
#   - 특정 유입 경로에서 `event_name = purchase`까지 이어지는 전환율 분석.
#
# #### **③ 사용자 세그멘테이션 (User Segmentation)**
# > **목표:** Notion 사용자 유형을 구분하고 맞춤형 전략을 세우기.
#
# - **사용자 그룹 분류**
#   - `user_id`, `event_name`, `event_timestamp` 등을 활용해 사용자의 주요 활동을 기준으로 그룹화.
#   - 예: 활성 사용자(Active Users) vs. 휴면 사용자(Churned Users) 구분.
#
# - **고객 평생 가치 분석 (Customer Lifetime Value, CLV)**
#   - `event_value_in_usd` 및 `user_id`별 총 매출을 기반으로 LTV 예측.
#
# ---
#
# ### **3. 분석 방법론 및 도구 추천**
# #### **① 기본 분석**
# - **Python을 활용한 데이터 탐색 (Pandas, Matplotlib, Seaborn)**
# - **SQL 활용 (BigQuery, Snowflake 등)**: 대용량 데이터 분석 시 필요
#
# #### **② 심화 분석**
# - **세그멘테이션 & 머신러닝 모델**
#   - K-Means Clustering을 사용하여 유저 그룹화
#   - Random Forest를 활용한 전환 예측 모델링
# - **마케팅 효과 분석**
#   - GA4 데이터와 결합하여 A/B 테스트 및 다중 터치포인트 분석 (Attribution Modeling)
#
# ---
#
# ### **4. 분석 우선순위 및 로드맵**
# | 단계 | 분석 목표 | 주요 지표 | 예상 결과 |
# |------|---------|----------|-----------|
# | **1주차** | 데이터 정리 및 탐색 | NULL 값, 이상치 처리 | 데이터 클리닝 완료 |
# | **2주차** | 사용자 행동 분석 | 세션 길이, 이벤트 흐름 | 사용자 페르소나 도출 |
# | **3주차** | 전환 분석 | 전환율, 주요 이벤트 | 퍼널 분석 결과 |
# | **4주차** | 마케팅 효과 분석 | 광고 성과, 유입 경로별 성과 | 광고 최적화 전략 |
# | **5주차** | 사용자 세그멘테이션 | CLV, LTV | 타겟 고객 세그먼트 도출 |
#
# ---
#
# ### **결론**
# - **사용자 행동 데이터와 마케팅 데이터를 결합하여 Notion의 고객 여정을 분석**하면, 전환율 최적화와 광고 예산 최적화가 가능할 것으로 보임.
# - **우선순위:** 사용자 행동 분석 → 전환율 분석 → 마케팅 성과 분석 → 사용자 세그멘테이션

# %%
# 기술 통계 분석 및 NULL 값이 모두 포함된 컬럼 찾기

# NULL 값이 있는 컬럼 확인
null_counts = df.isnull().sum()

# 모든 값이 NULL인 컬럼 찾기
null_columns = null_counts[null_counts == df.shape[0]].index.tolist()

# 기술 통계 확인 (수치형 데이터만)
numeric_summary = df.describe()

# 기술 통계 확인 (범주형 데이터 요약)
categorical_summary = df.describe(include=["object"])

# NULL 값만 포함된 컬럼 리스트와 기술 통계 출력
print(f"Null 값이 있는 컬럼:\n{null_counts}\n\n\n")
print(f"모든 값이 Null인 컬럼:\n{null_columns}\n\n\n")
print(f"수치형 기술통계:\n{numeric_summary}\n\n\n")
print(f"범주형 기술통계:\n{categorical_summary}")
# Out:
# Null 값이 있는 컬럼:
# event_date                                                                                         0
# event_timestamp                                                                                    0
# event_name                                                                                         0
# event_previous_timestamp                                                                         139
# event_value_in_usd                                                                              1440
#                                                                                                 ...
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.site_id         0
# session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.site_name       0
# session_traffic_source_last_click.session_traffic_source_last_click.dv360_campaign              1440
# publisher.publisher                                                                             1440
# time_diff                                                                                        139
# Length: 212, dtype: int64
#
#
#
# 모든 값이 Null인 컬럼:
# ['event_value_in_usd', 'batch_page_id', 'batch_ordering_id', 'items.item_revenue_in_usd', 'items.item_revenue', 'items.item_refund_in_usd', 'items.item_refund', 'user_ltv.user_ltv', 'device.device.advertising_id', 'device.device.browser', 'device.device.browser_version', 'device.device.web_info', 'app_info.app_info.install_store', 'traffic_source.traffic_source', 'event_dimensions.event_dimensions', 'ecommerce.ecommerce', 'ecommerce.ecommerce.purchase_revenue_in_usd', 'ecommerce.ecommerce.purchase_revenue', 'ecommerce.ecommerce.refund_value_in_usd', 'ecommerce.ecommerce.refund_value', 'ecommerce.ecommerce.shipping_value_in_usd', 'ecommerce.ecommerce.shipping_value', 'ecommerce.ecommerce.tax_value_in_usd', 'ecommerce.ecommerce.tax_value', 'collected_traffic_source.collected_traffic_source', 'collected_traffic_source.collected_traffic_source.manual_campaign_id', 'collected_traffic_source.collected_traffic_source.manual_medium', 'collected_traffic_source.collected_traffic_source.manual_term', 'collected_traffic_source.collected_traffic_source.manual_content', 'collected_traffic_source.collected_traffic_source.manual_source_platform', 'collected_traffic_source.collected_traffic_source.manual_creative_format', 'collected_traffic_source.collected_traffic_source.manual_marketing_tactic', 'collected_traffic_source.collected_traffic_source.gclid', 'collected_traffic_source.collected_traffic_source.dclid', 'collected_traffic_source.collected_traffic_source.srsltid', 'session_traffic_source_last_click.session_traffic_source_last_click.google_ads_campaign', 'session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.campaign_id', 'session_traffic_source_last_click.session_traffic_source_last_click.sa360_campaign', 'session_traffic_source_last_click.session_traffic_source_last_click.dv360_campaign', 'publisher.publisher']
#
#
#
# 수치형 기술통계:
#        event_date  event_value_in_usd  event_bundle_sequence_id  \
# count      1440.0                 0.0               1440.000000
# mean   20241113.0                 NaN                153.092361
# std           0.0                 NaN                205.863487
# min    20241113.0                 NaN                  2.000000
# 25%    20241113.0                 NaN                  7.000000
# 50%    20241113.0                 NaN                 38.000000
# 75%    20241113.0                 NaN                468.000000
# max    20241113.0                 NaN                523.000000
#
#        event_server_timestamp_offset        user_id     stream_id  \
# count                   1.440000e+03     834.000000  1.440000e+03
# mean                    6.993021e+05  115513.395683  2.330073e+09
# std                     5.300954e+06   38964.994957  1.288719e+04
# min                     1.090000e+02   19947.000000  2.330053e+09
# 25%                     2.268280e+05  117468.000000  2.330053e+09
# 50%                     2.991165e+05  136163.000000  2.330081e+09
# 75%                     3.849370e+05  136163.000000  2.330081e+09
# max                     8.248770e+07  140171.000000  2.330081e+09
#
#        batch_event_index  batch_page_id  batch_ordering_id  items.item_id  \
# count        1440.000000            0.0                0.0       7.000000
# mean           11.627778            NaN                NaN  522106.571429
# std            13.098082            NaN                NaN  167028.781889
# min             1.000000            NaN                NaN  284070.000000
# 25%             3.000000            NaN                NaN  425260.500000
# 50%             6.000000            NaN                NaN  566451.000000
# 75%            16.000000            NaN                NaN  649057.000000
# max            76.000000            NaN                NaN  655590.000000
#
#        ...  \
# count  ...
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        collected_traffic_source.collected_traffic_source.manual_creative_format  \
# count                                                                       0.0
# mean                                                                        NaN
# std                                                                         NaN
# min                                                                         NaN
# 25%                                                                         NaN
# 50%                                                                         NaN
# 75%                                                                         NaN
# max                                                                         NaN
#
#        collected_traffic_source.collected_traffic_source.manual_marketing_tactic  \
# count                                                                        0.0
# mean                                                                         NaN
# std                                                                          NaN
# min                                                                          NaN
# 25%                                                                          NaN
# 50%                                                                          NaN
# 75%                                                                          NaN
# max                                                                          NaN
#
#        collected_traffic_source.collected_traffic_source.gclid  \
# count                                                      0.0
# mean                                                       NaN
# std                                                        NaN
# min                                                        NaN
# 25%                                                        NaN
# 50%                                                        NaN
# 75%                                                        NaN
# max                                                        NaN
#
#        collected_traffic_source.collected_traffic_source.dclid  \
# count                                                      0.0
# mean                                                       NaN
# std                                                        NaN
# min                                                        NaN
# 25%                                                        NaN
# 50%                                                        NaN
# 75%                                                        NaN
# max                                                        NaN
#
#        collected_traffic_source.collected_traffic_source.srsltid  \
# count                                                        0.0
# mean                                                         NaN
# std                                                          NaN
# min                                                          NaN
# 25%                                                          NaN
# 50%                                                          NaN
# 75%                                                          NaN
# max                                                          NaN
#
#        session_traffic_source_last_click.session_traffic_source_last_click.google_ads_campaign  \
# count                                                                                      0.0
# mean                                                                                       NaN
# std                                                                                        NaN
# min                                                                                        NaN
# 25%                                                                                        NaN
# 50%                                                                                        NaN
# 75%                                                                                        NaN
# max                                                                                        NaN
#
#        session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.campaign_id  \
# count                                                                                                     0.0
# mean                                                                                                      NaN
# std                                                                                                       NaN
# min                                                                                                       NaN
# 25%                                                                                                       NaN
# 50%                                                                                                       NaN
# 75%                                                                                                       NaN
# max                                                                                                       NaN
#
#        session_traffic_source_last_click.session_traffic_source_last_click.sa360_campaign  \
# count                                                                                 0.0
# mean                                                                                  NaN
# std                                                                                   NaN
# min                                                                                   NaN
# 25%                                                                                   NaN
# 50%                                                                                   NaN
# 75%                                                                                   NaN
# max                                                                                   NaN
#
#        session_traffic_source_last_click.session_traffic_source_last_click.dv360_campaign  \
# count                                                                                 0.0
# mean                                                                                  NaN
# std                                                                                   NaN
# min                                                                                   NaN
# 25%                                                                                   NaN
# 50%                                                                                   NaN
# 75%                                                                                   NaN
# max                                                                                   NaN
#
#        publisher.publisher
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN
#
# [8 rows x 73 columns]
#
#
#
# 범주형 기술통계:
#                          event_timestamp   event_name  \
# count                               1440         1440
# unique                              1440           32
# top     2024-11-13 00:06:00.541000+09:00  screen_view
# freq                                   1          500
#
#                 event_previous_timestamp                    user_pseudo_id  \
# count                               1301                              1440
# unique                              1301                               103
# top     2024-11-12 23:58:23.577000+09:00  8AD0EDA3E1FF43669A39203848369A51
# freq                                   1                               350
#
#               user_first_touch_timestamp platform  \
# count                               1440     1440
# unique                               103        2
# top     2024-10-13 21:32:00.991000+09:00      IOS
# freq                                 350     1026
#
#                                                     items.item_name  \
# count                                                             7
# unique                                                            4
# top     클럽 Club C Revenge GX0386 White, Collegiate Gold & Bold Purp
# freq                                                              2
#
#        items.item_brand items.item_variant items.item_category  ...  \
# count                 7                  7                   7  ...
# unique                4                  1                   1  ...
# top                  리복          (not set)           (not set)  ...
# freq                  2                  7                   7  ...
#
#        session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.creative_type  \
# count                                                                                              1440
# unique                                                                                                1
# top                                                                                           (not set)
# freq                                                                                               1440
#
#        session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.creative_type_id  \
# count                                                                                                 1440
# unique                                                                                                   1
# top                                                                                              (not set)
# freq                                                                                                  1440
#
#        session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.creative_version  \
# count                                                                                                 1440
# unique                                                                                                   1
# top                                                                                              (not set)
# freq                                                                                                  1440
#
#        session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.placement_id  \
# count                                                                                             1440
# unique                                                                                               1
# top                                                                                          (not set)
# freq                                                                                              1440
#
#        session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.placement_cost_structure  \
# count                                                                                                         1440
# unique                                                                                                           1
# top                                                                                                      (not set)
# freq                                                                                                          1440
#
#        session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.placement_name  \
# count                                                                                               1440
# unique                                                                                                 1
# top                                                                                            (not set)
# freq                                                                                                1440
#
#        session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.rendering_id  \
# count                                                                                             1440
# unique                                                                                               1
# top                                                                                          (not set)
# freq                                                                                              1440
#
#        session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.site_id  \
# count                                                                                        1440
# unique                                                                                          1
# top                                                                                     (not set)
# freq                                                                                         1440
#
#        session_traffic_source_last_click.session_traffic_source_last_click.cm360_campaign.site_name  \
# count                                                                                          1440
# unique                                                                                            1
# top                                                                                       (not set)
# freq                                                                                           1440
#
#               time_diff
# count              1301
# unique             1157
# top     0 days 00:00:00
# freq                  6
#
# [4 rows x 138 columns]

# %%
# prompt: null_columns의 개수

print(f"Number of columns with only null values: {len(null_columns)}")
# Out:
# Number of columns with only null values: 40

# %%
null_columns
# Out:
# ['event_value_in_usd',
#  'batch_page_id',
#  'batch_ordering_id',
#  'items.item_revenue_in_usd',
#  'items.item_revenue',
#  'items.item_refund_in_usd',
#  'items.item_refund',
#  'user_ltv.user_ltv',
#  'device.device.advertising_id',
#  'device.device.browser',
#  'device.device.browser_version',
#  'device.device.web_info',
#  'app_info.app_info.install_store',
#  'traffic_source.traffic_source',
#  'event_dimensions.event_dimensions',
#  'ecommerce.ecommerce',
#  'ecommerce.ecommerce.purchase_revenue_in_usd',
#  'ecommerce.ecommerce.purchase_revenue',
#  'ecommerce.ecommerce.refund_value_in_usd',
#  'ecommerce.ecommerce.refund_value',
#  'ecommerce.ecommerce.shipping_value_in_usd',
#  'ecommerce.ecommerce.shipping_value',
#  'ecommerce.ecommerce.tax_value_in_usd',
#  'ecommerce.ecommerce.tax_value',
#  'collected_traffic_source.collected_traffic_source',
#  'collected_traffic_source.collected_traffic_source.manual_campaign_id',
#  'collected_traffic_source.collected_traffic_source.manual_medium',
#  'collected_traffic_source.collected_traffic_source.manual_term',
#  'collected_traffic_source.collected_traffic_source.manual_content',
#  'collected_traffic_source.collected_traffic_source.manual_source_platform',
#  'collected_traffic_source.collected_traffic_source.manual_creative_format',
#  'collected_traffic_source.collected_traffic_source.manual_marketing_tactic',
#  'collected_traffic_source.collected_traffic_source.gclid',
#  'collected_traffic_source.collected_traffic_source.dclid',
#  'collected_traffic_source.collected_traffic_source.srsltid',
#  'session_traffic_source_last_click.session_traffic_source_last_click.google_ads_campaign',
#  'session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.campaign_id',
#  'session_traffic_source_last_click.session_traffic_source_last_click.sa360_campaign',
#  'session_traffic_source_last_click.session_traffic_source_last_click.dv360_campaign',
#  'publisher.publisher']

# %% [markdown]
# ### **기술 통계 분석 결과**
# #### **1. NULL 값만 포함된 컬럼 (제거 대상)**
# 총 **40개의 컬럼**이 모든 값이 NULL로 채워져 있음.
# 해당 컬럼은 분석에 필요 없으므로 제거하는 것이 적절함.
#
# **특이사항은, revenue가 null이란 것. 즉, 해당 데이터는 매출 발생이 의도되지 않았거나, 매출발생이 실패했단 것을 의미함.**
#
# - **이벤트 및 사용자 관련**
#   - `event_value_in_usd`
#   - `batch_page_id`, `batch_ordering_id`
#   - `items.item_revenue_in_usd`, `items.item_revenue`
#   - `items.item_refund_in_usd`, `items.item_refund`
#   - `user_ltv.user_ltv`
#   - `device.device.advertising_id`
#   - `device.device.browser`, `device.device.browser_version`, `device.device.web_info`
#
# - **앱 및 트래픽 소스 관련**
#   - `app_info.app_info.install_store`
#   - `traffic_source.traffic_source`
#   - `event_dimensions.event_dimensions`
#   - `ecommerce.ecommerce`, `ecommerce.ecommerce.purchase_revenue_in_usd`, `ecommerce.ecommerce.purchase_revenue`
#   - `ecommerce.ecommerce.refund_value_in_usd`, `ecommerce.ecommerce.refund_value`
#   - `ecommerce.ecommerce.shipping_value_in_usd`, `ecommerce.ecommerce.shipping_value`
#   - `ecommerce.ecommerce.tax_value_in_usd`, `ecommerce.ecommerce.tax_value`
#   - `collected_traffic_source.collected_traffic_source.* (8개 컬럼)`
#   - `session_traffic_source_last_click.session_traffic_source_last_click.google_ads_campaign`
#   - `session_traffic_source_last_click.session_traffic_source_last_click.cross_channel_campaign.campaign_id`
#   - `session_traffic_source_last_click.session_traffic_source_last_click.sa360_campaign`
#   - `session_traffic_source_last_click.session_traffic_source_last_click.dv360_campaign`
#   - `publisher.publisher`

# %%
# NULL 값만 포함된 컬럼 제거
df_cleaned = df.drop(columns=null_columns)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Columns: 172 entries, event_date to time_diff
# dtypes: bool(1), float64(23), int64(10), object(138)
# memory usage: 1.9+ MB

# %% [markdown]
# ###사용자 행동 분석을 위한 탐색적 데이터 분석(EDA)을 수행
# ####*주요 분석 방향*
#
# 1. 이벤트별 발생 빈도 분석 (event_name 기준)
# 2. 사용자별 행동 및 체류 시간 분석 (user_id, user_pseudo_id, time_diff 활용)
# 3. 유입 채널 분석 (session_traffic_source_last_click 관련 데이터)
# 4. 코호트 분석 (user_first_touch_timestamp 기반)

# %%
# 이벤트별 발생 빈도 계산 (전체)
event_counts = df_cleaned['event_name'].value_counts()

# 상위 10개 이벤트만 출력
event_counts_top10 = event_counts.head(10)

# 상위 10개 이벤트 데이터를 데이터프레임으로 변환
event_counts_top10_df = event_counts_top10.reset_index()
event_counts_top10_df.columns = ['event_name', 'count']

# %%
print(event_counts_top10_df)
# Out:
#               event_name  count
# 0            screen_view    500
# 1        user_engagement    386
# 2     sign_up_step_click    127
# 3                 scroll    100
# 4  style_recommend_click     66
# 5          session_start     41
# 6          fnb_tab_click     38
# 7     main_content_click     37
# 8        eot_start_click     25
# 9       style_type_click     21

# %%
# 1) user_id 유무에 따른 그룹 나누기
df_cleaned['user_group'] = df_cleaned['user_id'].apply(lambda x: 'registered' if pd.notnull(x) else 'guest')

# 2) user_pseudo_id를 기준으로 그룹화하여 행동 흐름 분석
user_event_sequence = df_cleaned.groupby(['user_group', 'user_pseudo_id'])['event_name'].apply(list).reset_index()

# 3) event 간의 소요 시간(time_diff) 분석
df_cleaned['time_diff_seconds'] = pd.to_timedelta(df_cleaned['time_diff']).dt.total_seconds()

# user_pseudo_id별 평균 이벤트 간 소요 시간 계산
user_time_analysis = df_cleaned.groupby(['user_group', 'user_pseudo_id'])['time_diff_seconds'].mean().reset_index()

# %%
print(f'유저행동분석:{user_event_sequence}\n\n\n')
print(f'시간분석:{user_time_analysis}')
# Out:
# 유저행동분석:     user_group                    user_pseudo_id  \
# 0         guest  00378b72b7a38e0a11cd14fc26a6a762
# 1         guest  048AD36251DA482C9E82C8EF24842AA2
# 2         guest  0B8F194B8A5E409AA74C4EA7B879F493
# 3         guest  0E7F01E5F9264849BA869F8E902473A0
# 4         guest  12813D789587429785C883D2384E5EDE
# ..          ...                               ...
# 106  registered  b6cb139e9d4d4301afaa6706182c8c61
# 107  registered  ba7708d74e9cf97dbe428d79dcb7404a
# 108  registered  baeb24c0b5e6818b5f87cf5e95d654af
# 109  registered  e1c1ec34d5378fd2533e3fc71b01ca60
# 110  registered  f5ece5e70f630a706e71ca58134ebfdf
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        event_name
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [screen_view, screen_view, screen_view, sign_up_step_click, screen_view]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [screen_view]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [user_engagement, sign_up_step_click, screen_view, user_engagement, sign_up_step_click, user_engagement, screen_view, scroll, scroll]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                      [user_engagement, screen_view, screen_view, screen_view, user_engagement, user_engagement, sign_up_step_click, sign_up_step_click, sign_up_step_click, user_engagement, screen_view, screen_view, user_engagement, scroll]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [app_update, user_engagement, eot_start_click, user_engagement]
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 106                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [session_start, screen_view, screen_view, user_engagement, fnb_tab_click, screen_view, user_engagement]
# 107                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [login, scroll, scroll, screen_view, scroll, scroll, scroll, user_engagement]
# 108                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [login, user_engagement, session_start, screen_view, user_engagement]
# 109                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [session_start, screen_view, notification_receive, notification_foreground, scroll, screen_view, scroll, user_engagement]
# 110  [login, sign_up, screen_view, sign_up_step_click, screen_view, sign_up_step_click, sign_up_step_click, screen_view, sign_up_step_click, screen_view, sign_up_step_click, screen_view, sign_up_step_click, screen_view, sign_up_step_click, screen_view, sign_up_step_click, screen_view, sign_up_step_click, screen_view, sign_up_step_click, screen_view, sign_up_step_click, screen_view, sign_up_step_click, screen_view, sign_up_step_click, screen_view, notification_receive, notification_foreground, user_engagement, scroll, scroll, scroll, scroll, screen_view, scroll, screen_view, fnb_tab_click, screen_view, user_engagement]
#
# [111 rows x 3 columns]
#
#
#
# 시간분석:     user_group                    user_pseudo_id  time_diff_seconds
# 0         guest  00378b72b7a38e0a11cd14fc26a6a762       7.324200e+00
# 1         guest  048AD36251DA482C9E82C8EF24842AA2                NaN
# 2         guest  0B8F194B8A5E409AA74C4EA7B879F493       8.946667e+00
# 3         guest  0E7F01E5F9264849BA869F8E902473A0       2.089915e+01
# 4         guest  12813D789587429785C883D2384E5EDE       9.614769e+06
# ..          ...                               ...                ...
# 106  registered  b6cb139e9d4d4301afaa6706182c8c61       5.167437e+05
# 107  registered  ba7708d74e9cf97dbe428d79dcb7404a       8.160667e+00
# 108  registered  baeb24c0b5e6818b5f87cf5e95d654af       5.053460e+03
# 109  registered  e1c1ec34d5378fd2533e3fc71b01ca60       2.050108e+05
# 110  registered  f5ece5e70f630a706e71ca58134ebfdf       3.221665e+03
#
# [111 rows x 3 columns]

# %% [markdown]
# ###분석 결과
# 1. 사용자 그룹화
#
# * registered (로그인한 사용자) 28명
# * guest (비로그인 사용자) 83명
# → 이 두 그룹으로 나누어 행동 패턴을 분석.
#
# 2. 행동 흐름 (User Behavior Flow)
#
# * user_pseudo_id를 기준으로 각 사용자의 이벤트 시퀀스를 정리.
# * 특정 사용자들이 어떤 이벤트 흐름을 따르는지 확인 가능.
# * 이를 통해 대표적인 사용자 행동 패턴을 도출할 수 있음.
# * 이벤트 간 평균 소요 시간 (Time Diff Analysis)
#
# 3. time_diff_seconds 변수 활용.
# * user_pseudo_id별 평균 이벤트 간 소요 시간을 계산.
# * 일부 사용자는 이벤트 간 시간이 길고, 일부는 짧은 패턴을 보임.

# %%
# prompt: user_event_sequence를 csv파일로 출력

user_event_sequence.to_csv('user_event_sequence.csv', index=False, encoding='utf-8-sig')
